# %%
import helpers
import numpy as np
import re
import math
from tqdm import tqdm
import copy
import networkx as nx

data = """6,10
0,14
9,10
0,3
10,4
4,11
6,0
6,12
4,1
0,13
10,12
3,4
3,0
8,4
1,10
2,14
8,10
9,0

fold along y=7
fold along x=5"""

with open("input_13_custom.txt", 'r') as f:
    data = f.read()
#changeDict = {"forward": np.array([1,0]), "down": np.array([0,1]), "up": np.array([0,-1])}
#data = re.findall("(\d+),(\d+) -> (\d+),(\d+)", data)
#data = [x.rstrip() for x in data.split("\n\n") if x]

#data = """0,4
#0,6
#1,4
#1,5
#1,6
#2,5
#2,6
#
#fold along y=3"""

data = data.lstrip()
data = data.rstrip()
coords, instructions = data.split("\n\n")
instructions = [x.split(" ")[-1]  for x in instructions.split("\n")]
coords = set([tuple(int(y) for y in x.split(","))  for x in coords.split("\n")])
#data = [x.split("-") for x in data.split("\n")]
coords
#nprintCoords(coords)
# Out:
# {(74877211728, 1519951910),
#  (14657333394, 1486944984),
#  (16938998651, 1254540568),
#  (77755136754, 1358121544),
#  (7808250480, 248357262),
#  (72526763887, 1236696385),
#  (71957418673, 10222452),
#  (24105940970, 876081663),
#  (68360162272, 1340513879),
#  (78570288977, 1494166568),
#  (19499346959, 95155281),
#  (6668898275, 31565464),
#  (71981134611, 1274649263),
#  (1348737986, 1237234071),
#  (20657210900, 1342929030),
#  (30316333549, 608139794),
#  (32819507428, 665355780),
#  (9597211822, 794656612),
#  (41660492612, 242496527),
#  (21861368002, 992878708),
#  (18793587881, 505381035),
#  (39834478450, 551538372),
#  (33858515402, 308230536),
#  (5639219679, 470792486),
#  (1209088940, 347161076),
#  (62608106918, 203804403),
#  (28736288888, 662572148),
#  (38529478178, 532519785),
#  (74673576721, 337519466),
#  (66330831779, 235614787),
#  (52559086754, 5766791),
#  (7092277129, 297152700),
#  (32427416451, 1310327532),
#  (34032048029, 303180189),
# ...

# %%
#from PIL import Image
def nprintCoords(coord):
    x_s = 0
    y_s = 0
    for x,y in coord:
        if x > x_s:
            x_s = x
        if y > y_s:
            y_s = y
    arr = np.zeros((y_s+1,x_s+1))
    for x,y in coord:
        arr[y,x] = 1
    helpers.npNicePrint(arr)
    #im = Image.fromarray(np.uint8(arr * 255) , 'L')
    #im = Image.fromarray(self.grid).convert('1')
    #im.save(f"13_custom.png")

# %%
for instruction in instructions:
    fold_type, fold = instruction.split("=")
    fold = int(fold)
    newCoords = set()
    print(fold, fold_type)
    for x,y in coords:
        if y < fold and fold_type == "y":
            newCoords.add((x,y))
        if y > fold and fold_type == "y":
            newCoords.add((x, 2*fold - y))
        if x < fold and fold_type == "x":
            newCoords.add((x,y))
        if x > fold and fold_type == "x":
            newCoords.add((2*fold-x,y))
    print(len(newCoords))
    nprintCoords(newCoords)
    coords = newCoords
#nprintCoords(coords)
# Out:
# 39692221130 x
# 18968
# 19846210550 x
# 18968
# 9923747801 x
# 18968
# 767099149 y
# 18968
# 4962389024 x
# 18968
# 2481360713 x
# 18968
# 383560925 y
# 18968
# 1240814486 x
# 18968
# 620412706 x
# 18968
# 191784120 y
# 18968
# 310212538 x
# 18968
# 95893313 y
# 18968
# 155110217 x
# 18968
# 77569044 x
# 18968
# 38786153 x
# 18968
# 47952775 y
# 18968
# 19394080 x
# 18968
# 23976499 y
# 18968
# 9697234 x
# 18968
# 11988443 y
# 18968
# 4848904 x
# 18968
# 2424485 x
# 18968
# 1212252 x
# 18968
# 606158 x
# 18968
# 303093 x
# 18968
# 5994490 y
# 18968
# 151546 x
# 18968
# 75773 x
# 18968
# 2997296 y
# 18968
# 1498910 y
# 18968
# 37886 x
# 18968
# 18943 x
# 18968
# 749501 y
# 18968
# 374750 y
# 18968
# 187377 y
# 18968
# 93688 y
# 18968
# 46845 y
# 18968
# 9471 x
# 18968
# 23422 y
# 18968
# 4735 x
# 18968
# 11711 y
# 18968
# 2367 x
# 18968
# 5855 y
# 18968
# 1183 x
# 18968
# 591 x
# 18968
# 295 x
# 18968
# 147 x
# 18968
# 2927 y
# 18968
# 1463 y
# 18968
# 731 y
# 18968
# ...
