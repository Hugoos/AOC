# %%
import helpers
import numpy as np
import re 

#helpers.npNicePrint(arr)

data = """029A
980A
179A
456A
379A"""

with open("input_21.txt", 'r') as f:
    data = f.read().rstrip()

#print(colors, designs)


def safe_get(grid, index):
    try:
        return grid[tuple(index)]
    except:
        return ""
    
#changeDict = {"forward": np.array([1,0]), "down": np.array([0,1]), "up": np.array([0,-1])}
#data = [changeDict[x.split(" ")[0]] * int(x.split(" ")[1]) for x in data.split("\n") if x]

#np.prod(sum(data))    
#data = [list(map(int, x.split(" "))) for x in data.split('\n') if not x == ""]

#data = [(int(row.split(",")[0]),int(row.split(",")[1])) for row in data.split("\n")]

#grid, moves = data.split("\n\n")
#moves = moves.replace("\n", "")

#grid = {(x,y): str(val) for y, r in enumerate(data.split('\n')) for x, val in enumerate(r)}
#grid
data = [str(x) for x in data.split("\n")]
#data

# Output the parsed data
#print(data)


#grid = {(x,y): "." for x in range(max_coor+1) for y in range(max_coor+1)}

#helpers.visualize_dict_grid(grid)

# %%
from collections import deque

# Updated grid layout
grid = {
    '7': (0, 0), '8': (1, 0), '9': (2, 0),
    '4': (0, 1), '5': (1, 1), '6': (2, 1),
    '1': (0, 2), '2': (1, 2), '3': (2, 2),
                 '0': (1, 3), 'A': (2, 3)
}

# Directions for movement and their corresponding symbols
directions = {
    (0, -1): '^',  # Up
    (0, 1): 'v',   # Down
    (-1, 0): '<',  # Left
    (1, 0): '>'    # Right
}

# BFS to find all shortest paths
def bfs_all_shortest_paths(start, end, grid):
    start_coord = grid[start]
    end_coord = grid[end]
    queue = deque([(start_coord, [])])  # (current position, path taken)
    visited = set()
    shortest_paths = []
    shortest_length = None

    while queue:
        current, path = queue.popleft()

        # Stop exploring paths longer than the shortest found
        if shortest_length is not None and len(path) > shortest_length:
            continue

        # If we reach the destination
        if current == end_coord:
            if shortest_length is None:
                shortest_length = len(path)  # Record the shortest path length
            shortest_paths.append(path)
            continue

        # Mark current as visited
        visited.add(current)

        # Explore all valid neighbors
        for move, symbol in directions.items():
            neighbor = (current[0] + move[0], current[1] + move[1])
            if neighbor in grid.values() and neighbor not in visited:
                queue.append((neighbor, path + [symbol]))

    return set([''.join(path)+"A" for path in shortest_paths])

# Generate all shortest routes dictionary
num_grid = {
    key1: {
        key2: bfs_all_shortest_paths(key1, key2, grid) if key1 != key2 else []
        for key2 in grid
    }
    for key1 in grid
}
for k, v in num_grid.items():
    num_grid[k][k]= set("A")
    

# Example usage: Pretty print the all shortest routes
from pprint import pprint
pprint(num_grid)
# Out:
# {'0': {'0': {'A'},
#        '1': {'^<A'},
#        '2': {'^A'},
#        '3': {'>^A', '^>A'},
#        '4': {'^^<A', '^<^A'},
#        '5': {'^^A'},
#        '6': {'^>^A', '^^>A', '>^^A'},
#        '7': {'^<^^A', '^^^<A', '^^<^A'},
#        '8': {'^^^A'},
#        '9': {'^^>^A', '^^^>A', '>^^^A', '^>^^A'},
#        'A': {'>A'}},
#  '1': {'0': {'>vA'},
#        '1': {'A'},
#        '2': {'>A'},
#        '3': {'>>A'},
#        '4': {'^A'},
#        '5': {'>^A', '^>A'},
#        '6': {'>>^A', '^>>A', '>^>A'},
#        '7': {'^^A'},
#        '8': {'^>^A', '^^>A', '>^^A'},
#        '9': {'>^^>A', '^>^>A', '>>^^A', '^^>>A', '^>>^A', '>^>^A'},
#        'A': {'>v>A', '>>vA'}},
#  '2': {'0': {'vA'},
#        '1': {'<A'},
#        '2': {'A'},
#        '3': {'>A'},
#        '4': {'^<A', '<^A'},
#        '5': {'^A'},
#        '6': {'>^A', '^>A'},
#        '7': {'^^<A', '^<^A', '<^^A'},
#        '8': {'^^A'},
#        '9': {'^>^A', '^^>A', '>^^A'},
#        'A': {'v>A', '>vA'}},
#  '3': {'0': {'<vA', 'v<A'},
#        '1': {'<<A'},
#        '2': {'<A'},
#        '3': {'A'},
#        '4': {'^<<A', '<^<A', '<<^A'},
#        '5': {'^<A', '<^A'},
#        '6': {'^A'},
#        '7': {'^<^<A', '^<<^A', '<<^^A', '^^<<A', '<^<^A', '<^^<A'},
#        '8': {'^^<A', '^<^A', '<^^A'},
#        '9': {'^^A'},
#        'A': {'vA'}},
#  '4': {'0': {'>vvA', 'v>vA'},
#        '1': {'vA'},
#        '2': {'v>A', '>vA'},
#        '3': {'>v>A', 'v>>A', '>>vA'},
#        '4': {'A'},
#        '5': {'>A'},
#        '6': {'>>A'},
#        '7': {'^A'},
#        '8': {'>^A', '^>A'},
#        '9': {'>>^A', '^>>A', '>^>A'},
#        'A': {'v>v>A', 'v>>vA', '>v>vA', '>>vvA', '>vv>A'}},
#  '5': {'0': {'vvA'},
#        '1': {'<vA', 'v<A'},
#        '2': {'vA'},
#        '3': {'v>A', '>vA'},
#        '4': {'<A'},
#        '5': {'A'},
#        '6': {'>A'},
#        '7': {'^<A', '<^A'},
#        '8': {'^A'},
#        '9': {'>^A', '^>A'},
#        'A': {'>vvA', 'v>vA', 'vv>A'}},
#  '6': {'0': {'vv<A', '<vvA', 'v<vA'},
#        '1': {'<v<A', 'v<<A', '<<vA'},
#        '2': {'<vA', 'v<A'},
#        '3': {'vA'},
#        '4': {'<<A'},
#        '5': {'<A'},
#        '6': {'A'},
#        '7': {'^<<A', '<^<A', '<<^A'},
#        '8': {'^<A', '<^A'},
#        '9': {'^A'},
#        'A': {'vvA'}},
#  '7': {'0': {'vv>vA', 'v>vvA', '>vvvA'},
#        '1': {'vvA'},
#        '2': {'>vvA', 'v>vA', 'vv>A'},
#        '3': {'v>v>A', 'v>>vA', '>v>vA', 'vv>>A', '>>vvA', '>vv>A'},
#        '4': {'vA'},
#        '5': {'v>A', '>vA'},
#        '6': {'>v>A', 'v>>A', '>>vA'},
#        '7': {'A'},
#        '8': {'>A'},
#        '9': {'>>A'},
#        'A': {'>>vvvA',
#              '>v>vvA',
#              '>vv>vA',
#              '>vvv>A',
#              'v>>vvA',
#              'v>v>vA',
#              'v>vv>A',
#              'vv>>vA',
#              'vv>v>A'}},
#  '8': {'0': {'vvvA'},
#        '1': {'vv<A', '<vvA', 'v<vA'},
#        '2': {'vvA'},
#        '3': {'>vvA', 'v>vA', 'vv>A'},
#        '4': {'<vA', 'v<A'},
#        '5': {'vA'},
#        '6': {'v>A', '>vA'},
#        '7': {'<A'},
#        '8': {'A'},
#        '9': {'>A'},
#        'A': {'vv>vA', 'v>vvA', 'vvv>A', '>vvvA'}},
#  '9': {'0': {'vvv<A', 'v<vvA', 'vv<vA', '<vvvA'},
#        '1': {'v<<vA', 'v<v<A', '<v<vA', 'vv<<A', '<vv<A', '<<vvA'},
#        '2': {'vv<A', '<vvA', 'v<vA'},
#        '3': {'vvA'},
#        '4': {'<v<A', 'v<<A', '<<vA'},
#        '5': {'<vA', 'v<A'},
#        '6': {'vA'},
#        '7': {'<<A'},
#        '8': {'<A'},
#        '9': {'A'},
#        'A': {'vvvA'}},
#  'A': {'0': {'<A'},
#        '1': {'^<<A', '<^<A'},
#        '2': {'^<A', '<^A'},
#        '3': {'^A'},
#        '4': {'^<^<A', '^<<^A', '^^<<A', '<^<^A', '<^^<A'},
#        '5': {'^^<A', '^<^A', '<^^A'},
#        '6': {'^^A'},
#        '7': {'<^<^^A',
#              '<^^<^A',
#              '<^^^<A',
#              '^<<^^A',
#              '^<^<^A',
#              '^<^^<A',
#              '^^<<^A',
#              '^^<^<A',
#              '^^^<<A'},
#        '8': {'<^^^A', '^<^^A', '^^^<A', '^^<^A'},
#        '9': {'^^^A'},
#        'A': {'A'}}}

# %%
key_pad_grid = {
                 '^': (1, 0), 'A': (2, 0),
    '<': (0, 1), 'v': (1, 1), '>': (2, 1)
}

key_pad = {
    key1: {
        key2: bfs_all_shortest_paths(key1, key2, key_pad_grid) if key1 != key2 else []
        for key2 in key_pad_grid
    }
    for key1 in key_pad_grid
}


for k, v in key_pad.items():
    key_pad[k][k] = set("A")
    
f_key_pad = {}

for outer_key, inner_dict in key_pad.items():
    for inner_key, value_set in inner_dict.items():
        # Concatenate all strings in the value set
        f_key_pad[f'{outer_key}{inner_key}'] = value_set

# Print the result
print(f_key_pad)
    

# Example usage: Pretty print the all shortest routes
from pprint import pprint
pprint(key_pad)
# Out:
# {'^^': {'A'}, '^A': {'>A'}, '^<': {'v<A'}, '^v': {'vA'}, '^>': {'v>A', '>vA'}, 'A^': {'<A'}, 'AA': {'A'}, 'A<': {'<v<A', 'v<<A'}, 'Av': {'<vA', 'v<A'}, 'A>': {'vA'}, '<^': {'>^A'}, '<A': {'>>^A', '>^>A'}, '<<': {'A'}, '<v': {'>A'}, '<>': {'>>A'}, 'v^': {'^A'}, 'vA': {'>^A', '^>A'}, 'v<': {'<A'}, 'vv': {'A'}, 'v>': {'>A'}, '>^': {'^<A', '<^A'}, '>A': {'^A'}, '><': {'<<A'}, '>v': {'<A'}, '>>': {'A'}}
# {'<': {'<': {'A'},
#        '>': {'>>A'},
#        'A': {'>>^A', '>^>A'},
#        '^': {'>^A'},
#        'v': {'>A'}},
#  '>': {'<': {'<<A'}, '>': {'A'}, 'A': {'^A'}, '^': {'^<A', '<^A'}, 'v': {'<A'}},
#  'A': {'<': {'<v<A', 'v<<A'},
#        '>': {'vA'},
#        'A': {'A'},
#        '^': {'<A'},
#        'v': {'<vA', 'v<A'}},
#  '^': {'<': {'v<A'}, '>': {'v>A', '>vA'}, 'A': {'>A'}, '^': {'A'}, 'v': {'vA'}},
#  'v': {'<': {'<A'}, '>': {'>A'}, 'A': {'>^A', '^>A'}, '^': {'^A'}, 'v': {'A'}}}

# %%
def get_min(row_set, curr_case):
    answers = []
    for s in row_set:
        s_A = "A" + s
        answers.append(sum([curr_case[s_A[i:i+2]] for i in range(0, len(s_A) - 1)]))
    return min(answers)

# %%
#layer 1
base_case = {k: len(list(v)[0]) for (k,v) in f_key_pad.items()} # 1 robot
true_dict = {k: get_min(v, base_case) for (k,v) in f_key_pad.items()} # 2 robots
for x in range(23): # + 23 robots
    true_dict = {k: get_min(v, true_dict) for (k,v) in f_key_pad.items()}
true_dict
# Out:
# {'^^': 1,
#  '^A': 5743602246,
#  '^<': 12192864309,
#  '^v': 8357534516,
#  '^>': 9156556999,
#  'A^': 9009012838,
#  'AA': 1,
#  'A<': 12192864310,
#  'Av': 11104086645,
#  'A>': 8357534516,
#  '<^': 10218188221,
#  '<A': 10218188222,
#  '<<': 1,
#  '<v': 5743602246,
#  '<>': 5743602247,
#  'v^': 5930403600,
#  'vA': 9686334009,
#  'v<': 9009012838,
#  'vv': 1,
#  'v>': 5743602246,
#  '>^': 11317884431,
#  '>A': 5930403600,
#  '><': 9009012839,
#  '>v': 9009012838,
#  '>>': 1}

# %%
ans = 0
for word in data:
    start_str = "A" + word
    for move_str in [start_str[i:i+2] for i in range(0, len(s_A) - 1)]:
        row_set = num_grid[move_str[0]][move_str[1]]
        ans += get_min(row_set, true_dict) * int(''.join(re.findall(r'\d+', word)))
ans
# Out:
# 231309103124520
