# %%
import helpers
import numpy as np
import re 
import networkx as nx

#helpers.npNicePrint(arr)

data = """#####
.####
.####
.####
.#.#.
.#...
.....

#####
##.##
.#.##
...##
...#.
...#.
.....

.....
#....
#....
#...#
#.#.#
#.###
#####

.....
.....
#.#..
###..
###.#
###.#
#####

.....
.....
.....
#....
#.#..
#.#.#
#####"""

with open("input_25.txt", 'r') as f:
    data = f.read().rstrip()

grids = data.split("\n\n")

def safe_get(grid, index):
    try:
        return grid[tuple(index)]
    except:
        return ""
    
#changeDict = {"forward": np.array([1,0]), "down": np.array([0,1]), "up": np.array([0,-1])}
#data = [changeDict[x.split(" ")[0]] * int(x.split(" ")[1]) for x in data.split("\n") if x]

#np.prod(sum(data))    
#data = [list(map(int, x.split(" "))) for x in data.split('\n') if not x == ""]

#data = [(int(row.split(",")[0]),int(row.split(",")[1])) for row in data.split("\n")]

#grid, moves = data.split("\n\n")
#moves = moves.replace("\n", "")

#grid = {(x,y): str(val) for y, r in enumerate(data.split('\n')) for x, val in enumerate(r)}
#grid
#data = [str(x).split("-") for x in data.split("\n")]
#data

# Output the parsed data
#print(data)

keys = []
locks = []

for grid in grids:
    rows = grid.split("\n")
    if all([x == "." for x in rows[0]]): 
        #print("key")
        id_key = [-1,-1,-1,-1,-1]
        for i, row in enumerate(reversed(rows)):
            for j, val in enumerate(row):
                if val == "#":
                    id_key[j] = i
        keys.append(id_key)
            
    else:
        #print("lock")
        if all([x == "#" for x in rows[0]]): 
            id_lock = [-1,-1,-1,-1,-1]
            for i, row in enumerate(reversed(rows)):
                for j, val in enumerate(row):
                    if val == ".":
                        id_lock[j] = i
            locks.append(id_lock)
    #or row in grid.split("\n"):
    #   print(row)

#grid = {(x,y): "." for x in range(max_coor+1) for y in range(max_coor+1)}

#helpers.visualize_dict_grid(grid)

# %%
seen = set()
ans = 0
for lock in locks:
    for key in keys:
        if tuple([tuple(lock), tuple(key)]) in seen:
            continue
        else:
            seen.add(tuple([tuple(lock), tuple(key)]))
        #print([x >= y for x,y in zip(lock,key)])
        ans += all([x >= y for x,y in zip(lock,key)])
ans
# Out:
# 3508
