# %%
# Define the list of rucksacks
rucksacks = [
    'vJrwpWtwJgWrhcsFMMfFFhFp',
    'jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL',
    'PmmdzqPrVvPwwTWBwg',
    'wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn',
    'ttgJtRGJQctTZtZT',
    'CrZsJsPPZsGzwwsLwLmpwMDw'
]
rucksacks = rucksacks2

# Initialize the total sum
total_sum = 0

# Loop through each rucksack
for rucksack in rucksacks:
    # Check if the first half of the items contains the same item type as the second half
    if len(set(rucksack[:len(rucksack)//2]) & set(rucksack[len(rucksack)//2:])) > 0:
        # Get the item type that appears in both compartments
        item_type = list(set(rucksack[:len(rucksack)//2]) & set(rucksack[len(rucksack)//2:]))[0]
        # Convert the item type to its ASCII value
        ascii_value = ord(item_type)
        # Calculate the priority of the item type
        priority = ascii_value - 96 if ascii_value >= 97 else ascii_value - 64
        # Add the priority to the total sum
        total_sum += priority

# Print the total sum
print(total_sum)
# Out:
# 3931

# %%
# List of rucksacks
rucksacks = [
    "vJrwpWtwJgWrhcsFMMfFFhFp",
    "jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL",
    "PmmdzqPrVvPwwTWBwg",
    "wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn",
    "ttgJtRGJQctTZtZT",
    "CrZsJsPPZsGzwwsLwLmpwMDw",
]

rucksacks = rucksacks2

# Compute the sum of priorities
sum_of_priorities = 0

# Iterate through the rucksacks
for rucksack in rucksacks:
    # Split the rucksack into two compartments
    first_compartment = rucksack[:len(rucksack) // 2]
    second_compartment = rucksack[len(rucksack) // 2:]

    # Iterate through the items in the first compartment
    for item in first_compartment:
        # Check if the item also appears in the second compartment
        if item in second_compartment:
            # Calculate the priority of the item
            priority = 1 + (ord(item) - ord('a'))

            # Add the priority to the sum of priorities
            sum_of_priorities += priority

# Print the sum of priorities
print(sum_of_priorities)
# Out:
# -1349

# %%
# create a list to store the priorities of the common item types
common_priorities = []
rucksacks = rucksacks2

# go through the list of rucksack items
for rucksack in rucksacks:
  # divide the rucksack items into two compartments
  first_compartment = rucksack[:len(rucksack)//2]
  second_compartment = rucksack[len(rucksack)//2:]
  
  # find the item types that appear in both compartments
  common_types = set(first_compartment) & set(second_compartment)
  
  # convert the item types to their priorities and add them to the list
  for item_type in common_types:
    priority = ord(item_type) - ord('a') + 1
    common_priorities.append(priority)

# sum up the priorities in the list to find the total priority
total_priority = sum(common_priorities)
total_priority
# Out:
# -741

# %%
# Parse the input to obtain a list of strings representing the items in each rucksack
rucksacks = rucksacks2

# For each rucksack, split the string into two equal-length substrings
for rucksack in rucksacks:
    first_compartment = rucksack[:len(rucksack) // 2]
    second_compartment = rucksack[len(rucksack) // 2:]
    
    # Find the item type that appears in both compartments by comparing the two substrings
    common_item = ""
    for item in first_compartment:
        if item in second_compartment:
            common_item = item
            break
    
    # Calculate the priority of the common item by converting its letter to a number
    priority = ord(common_item.lower()) - ord("a") + 1
    
    # Sum the priorities of all the item types to obtain the final answer
    total_priority += priority
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36108/794472062.py in <module>
#      15
#      16     # Calculate the priority of the common item by converting its letter to a number
# ---> 17     priority = ord(common_item.lower()) - ord("a") + 1
#      18
#      19     # Sum the priorities of all the item types to obtain the final answer
#
# TypeError: ord() expected a character, but string of length 0 found

# %%
# Parse the input to obtain a list of strings representing the items in each rucksack
rucksacks = ["vJrwpWtwJgWrhcsFMMfFFhFp", "jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL", "PmmdzqPrVvPwwTWBwg", "wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn", "ttgJtRGJQctTZtZT", "CrZsJsPPZsGzwwsLwLmpwMDw"]

# Initialize the total priority to 0
total_priority = 0

# For each rucksack, split the string into two equal-length substrings
for rucksack in rucksacks:
    first_compartment = rucksack[:len(rucksack) // 2]
    second_compartment = rucksack[len(rucksack) // 2:]
    
    # Find the item type that appears in both compartments by comparing the two substrings
    common_item = ""
    for item in first_compartment:
        if item in second_compartment:
            common_item = item
            break
    
    # Calculate the priority of the common item by converting its letter to a number
    priority = ord(common_item.lower()) - ord("a") + 1
    
    # Sum the priorities of all the item types to obtain the final answer
    total_priority += priority

# Print the final answer
print(total_priority)
# Out:
# 105

# %%
# Parse the input to obtain a list of strings representing the items in each rucksack
rucksacks = [
    "vJrwpWtwJgWrhcsFMMfFFhFp",
    "jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL",
    "PmmdzqPrVvPwwTWBwg",
    "wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn",
    "ttgJtRGJQctTZtZT",
    "CrZsJsPPZsGzwwsLwLmpwMDw"
]

total_priority = 0

# For each rucksack, split the string into two equal-length substrings
for rucksack in rucksacks:
    first_compartment = rucksack[:len(rucksack) // 2]
    second_compartment = rucksack[len(rucksack) // 2:]
    
    # Find the item type that appears in both compartments by comparing the two substrings
    common_item = ""
    for item in first_compartment:
        if item in second_compartment:
            common_item = item
            break
    
    # Calculate the priority of the common item by converting its letter to a number
    priority = ord(common_item.lower()) - ord("a") + 1
    
    # Sum the priorities of all the item types to obtain the final answer
    total_priority += priority

# Print the final answer
print(total_priority)
# Out:
# 105

# %%
# Parse the input to obtain a list of strings representing the items in each rucksack
rucksacks = [
    "vJrwpWtwJgWrhcsFMMfFFhFp",
    "jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL",
    "PmmdzqPrVvPwwTWBwg",
    "wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn",
    "ttgJtRGJQctTZtZT",
    "CrZsJsPPZsGzwwsLwLmpwMDw"
]
rucksacks = rucksacks2
total_priority = 0

# For each rucksack, split the string into two equal-length substrings
for rucksack in rucksacks:
    first_compartment = rucksack[:len(rucksack) // 2]
    second_compartment = rucksack[len(rucksack) // 2:]
    
    # Find the item type that appears in both compartments by comparing the two substrings
    common_item = ""
    for item in first_compartment:
        if item in second_compartment:
            common_item = item
            break
    
    # Calculate the priority of the common item by converting its letter to a number
    if common_item.islower():
        priority = ord(common_item) - ord("a") + 1
    elif common_item.isupper():
        priority = ord(common_item) - ord("A") + 27
    
    # Sum the priorities of all the item types to obtain the final answer
    total_priority += priority

# Print the final answer
print(total_priority)
# Out:
# 7727

# %%
rucksacks = """vJrwpWtwJgWrhcsFMMfFFhFp
jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
PmmdzqPrVvPwwTWBwg
wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
ttgJtRGJQctTZtZT
CrZsJsPPZsGzwwsLwLmpwMDw
"""
with open("input_3.txt", 'r') as f:
    rucksacks2 = [x for x in f.read().split("\n") if x]

# %%
rucksacks2
# Out:
# ['wgqJtbJMqZVTwWPZZT',
#  'LHcTGHQhzrTzBsZFPHFZWFFs',
#  'RnLRClzGzRGLGLGCNRjTMjJfgmffSffMqNgp',
#  'WPLgsfLmLgqZvZgSRR',
#  'RbwHdbDdQFFFMvvMjbhqhZZS',
#  'lzTdldBDszfGcRsr',
#  'ZjnhJjMjnbdnbHdFLmmfFLmnCCWFFl',
#  'PpNwtRsNsZSsRwCfzQQBfQszCBsC',
#  'PpwcqqVZRtbggggjcgJJ',
#  'ntczBcVcgnHzgBHnVntcBBFhgsmmmssqWNWNWqLvNhsqTN',
#  'bSSGdSDZbGSGdDmLmGTvTGmLFFhm',
#  'PlFbDpJDPbPdPbZQZDZlSCDBfMVRwBzBtBQzfzRHVMVRtH',
#  'fDVrmmrvcmCcVpfcfGlswpPwsttMpjJMPPjjtP',
#  'RgSTdndFLbJqqPssWWjPWjPjHS',
#  'FqgzQnTqJRRQqLLhTCDhDCDmcmlvvlhcVm',
#  'nnqVtHbfVHZVmtlvmHtZtrFSFTRRFhRccTbrLsLSGr',
#  'cCNJQJPJQgjjMQdDrGGsRhTFGFRFSpMS',
#  'gzdCwWdjNPgzcJgjwdZtVlHHmvvmZlvffHnz',
#  'FFgsgwNwWvggQsMWDwvQQvQcccdcJZDtJGBtVGGGtcVlzt',
#  'rjfTrbjpjRSRTbTpzldjjHBtJGBdltJG',
#  'RbrPTfpCfmbpmnfRRCvMvQWNBwFFgMsgBL',
#  'zzLHgjjjdFHWbGBjjzcbgQRmSvqsSpmRsRSQSmRMWv',
#  'ZfJVrwPhZhZlhQQqBSQSNSqM',
#  'tnCfrDCltfPzHFFLBgngHz',
#  'DCpwrrMhwCrCMVCpGFqpVDnWWTWBtnTWvWfvbbTdFWRv',
#  'lmhhcsQPmTtTnnPBTB',
# ...
