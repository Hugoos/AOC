# %%
html = """


<!doctype html>
<!--#####################################################################-->
<!--#   Deze webshop draait op het Next PRO platform van Logic4.        #-->
<!--#   Meer informatie? www.logic4.nl/oplossingen/webshop-software/    #-->
<!--#   All rights reserved.                                            #-->
<!--#####################################################################-->


<!--[if lt IE 7 ]> <html class="ie ie6" lang="nl"> <![endif]-->
<!--[if IE 7 ]>    <html class="ie ie7" lang="nl"> <![endif]-->
<!--[if IE 8 ]>    <html class="ie ie8" lang="nl"> <![endif]-->
<!--[if IE 9 ]>    <html class="ie ie9" lang="nl"> <![endif]-->
<!--[if gt IE 9]><!-->
<html id="MasterHtml" itemscope="" itemtype="http://schema.org/WebPage" lang="nl">
<!--<![endif]-->

<head prefix="og: http://ogp.me/ns#"><meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" /><meta name="format-detection" content="telephone=no" /><meta name="HandheldFriendly" content="true" /><meta name="MobileOptimized" content="320" />
    <!--[if IEMobile]><meta http-equiv="cleartype" content="on" /><![endif]-->

    <meta itemprop='name' content='Zoekopdracht: huzzle' />
<meta property='og:title' content='Zoekopdracht: huzzle' />
<meta itemprop='description' content='Zoekopdracht: huzzle' />
<meta property='og:description' content='Zoekopdracht: huzzle' />
<meta name='og:type' content='website'>
<meta property='og:url' content='https://www.spellenrijk.nl/zoeken.html' />
<meta itemprop='url' content='https://www.spellenrijk.nl/zoeken.html' />
<meta name='robots' content='noindex, nofollow' />
<meta name='googlebot' content='noindex'>
<meta property='og:image' content='https://www.spellenrijk.nl/styles/clients/spellenrijk-2020/img/logo.png' />
<meta itemprop='image' content='https://www.spellenrijk.nl/styles/clients/spellenrijk-2020/img/logo.png' />
<meta name="facebook-domain-verification" content="0fxiqrsewozaqxbwa1te82x2p50ew3" />

    <!-- Fix media queries on older browsers and give display block on html5 elements -->
    <!--[if lt IE 9]>
		<script src="https://oss.maxcdn.com/html5shiv/3.7.3/html5shiv.min.js"></script>  
		<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
    <![endif]-->
    <!--[if gte IE 9]>
        <style type="text/css">.gemengd,.goud,.metaal,.zilver {filter: none;}</style>
    <![endif]-->

    <link rel='apple-touch-icon' sizes='180x180' href='/styles/clients/spellenrijk-2020/img/favicon/apple-touch-icon.png'>
<link rel='icon' type='image/png' href='/styles/clients/spellenrijk-2020/img/favicon/favicon-32x32.png' sizes='32x32'>
<link rel='icon' type='image/png' href='/styles/clients/spellenrijk-2020/img/favicon/favicon-16x16.png' sizes='16x16'>
<link rel='manifest' href='/styles/clients/spellenrijk-2020/img/favicon/site.webmanifest'>
<link rel='mask-icon' href='/styles/clients/spellenrijk-2020/img/favicon/safari-pinned-tab.svg'>
<link rel='shortcut icon' href='/styles/clients/spellenrijk-2020/img/favicon/favicon.ico'>
<meta name='msapplication-config' content='/styles/clients/spellenrijk-2020/img/favicon/browserconfig.xml'>
<meta name='theme-color' content='#333333'>
<link href='/grid/css/z-bundle.1.3.min.css' rel='stylesheet' /><link href='/styles/clients/spellenrijk-2020/less/main.css?v=311022132721' rel='stylesheet'/>
    <script type="text/javascript" src="https://gc.kis.v2.scr.kaspersky-labs.com/FD126C42-EBFA-4E12-B309-BB3FDD723AC1/main.js?attr=MW0sWEYEsq-dTJP20-oaRQ5ek-tUFb02E581GOzGDAEhZuwV2jRAV7gUkB9aFnlxQWvTvFJb-9uAUMatXJ4e_yiN3K7EmOSNVlyUHk87Rx8" charset="UTF-8"></script><script type="text/javascript">
        //document.onreadystatechange = function () {var bum = document.getElementsByClassName('bumbli-wrap');if (bum != null) {for (var i = 0; i < bum.length; i++) {bum[i].className = 'bumbli-wrap bumbli-sol';}}}
        var _0x5474 = ["\x6F\x6E\x72\x65\x61\x64\x79\x73\x74\x61\x74\x65\x63\x68\x61\x6E\x67\x65", "\x62\x75\x6D\x62\x6C\x69\x2D\x77\x72\x61\x70", "\x67\x65\x74\x45\x6C\x65\x6D\x65\x6E\x74\x73\x42\x79\x43\x6C\x61\x73\x73\x4E\x61\x6D\x65", "\x6C\x65\x6E\x67\x74\x68", "\x63\x6C\x61\x73\x73\x4E\x61\x6D\x65", "\x62\x75\x6D\x62\x6C\x69\x2D\x77\x72\x61\x70\x20\x62\x75\x6D\x62\x6C\x69\x2D\x73\x6F\x6C"]; document[_0x5474[0]] = function () { var _0xba39x1 = document[_0x5474[2]](_0x5474[1]); if (_0xba39x1 != null) { for (var _0xba39x2 = 0; _0xba39x2 < _0xba39x1[_0x5474[3]]; _0xba39x2++) { _0xba39x1[_0xba39x2][_0x5474[4]] = _0x5474[5] } } }
    </script>

    <script>dataLayer = window.dataLayer = window.dataLayer || [];</script>
<!-- Google Tag Manager -->
<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j = d.createElement(s),dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src ='https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f); })
(window,document,'script','dataLayer','GTM-WFP3PZW');
dataLayer.push({ 'ecommerce':
{"currencyCode":"EUR","impressions":[{"position":0,"list":"products","quantity":1,"id":"515117","name":"Huzzle Cast Puzzle - Infinity (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":1,"list":"products","quantity":1,"id":"515084","name":"Huzzle Cast Puzzle - Laby (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":2,"list":"products","quantity":1,"id":"515055","name":"Huzzle Cast Puzzle - Coaster (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":3,"list":"products","quantity":1,"id":"515044","name":"Huzzle Cast Puzzle - Cross (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":4,"list":"products","quantity":1,"id":"515058","name":"Huzzle Cast Puzzle - Cylinder (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":5,"list":"products","quantity":1,"id":"515114","name":"Huzzle Cast Puzzle - Nutcase (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":6,"list":"products","quantity":1,"id":"515097","name":"Huzzle Cast Puzzle - Tube (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":7,"list":"products","quantity":1,"id":"515035","name":"Huzzle Cast Puzzle - O'gear (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":8,"list":"products","quantity":1,"id":"515068","name":"Huzzle Cast Puzzle - Planet (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":9,"list":"products","quantity":1,"id":"515115","name":"Huzzle Cast Puzzle - Quartet (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":10,"list":"products","quantity":1,"id":"515085","name":"Huzzle Cast Puzzle - Spiral (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":11,"list":"products","quantity":1,"id":"515118","name":"Huzzle Cast Puzzle - Trinity (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":12,"list":"products","quantity":1,"id":"515066","name":"Huzzle Cast Puzzle - UFO (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":13,"list":"products","quantity":1,"id":"515113","name":"Huzzle Cast Puzzle - Enigma (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":14,"list":"products","quantity":1,"id":"515095","name":"Huzzle Cast Puzzle - Padlock (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":15,"list":"products","quantity":1,"id":"515116","name":"Huzzle Cast Puzzle - Vortex (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":16,"list":"products","quantity":1,"id":"515003","name":"Huzzle Cast Puzzle - ABC (level 1)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":17,"list":"products","quantity":1,"id":"515082","name":"Huzzle Cast Puzzle - Amour (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":18,"list":"products","quantity":1,"id":"515041","name":"Huzzle Cast Puzzle - Arrows (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":19,"list":"products","quantity":1,"id":"515053","name":"Huzzle Cast Puzzle - Baroq (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":20,"list":"products","quantity":1,"id":"515014","name":"Huzzle Cast Puzzle - Box (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":21,"list":"products","quantity":1,"id":"515033","name":"Huzzle Cast Puzzle - Cage (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":22,"list":"products","quantity":1,"id":"515064","name":"Huzzle Cast Puzzle - Cake (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":23,"list":"products","quantity":1,"id":"515111","name":"Huzzle Cast Puzzle - Chain (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":24,"list":"products","quantity":1,"id":"515056","name":"Huzzle Cast Puzzle - Coil (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":25,"list":"products","quantity":1,"id":"515096","name":"Huzzle Cast Puzzle - Cyclone (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":26,"list":"products","quantity":1,"id":"515037","name":"Huzzle Cast Puzzle - Delta (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":27,"list":"products","quantity":1,"id":"515083","name":"Huzzle Cast Puzzle - Devil (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":28,"list":"products","quantity":1,"id":"515065","name":"Huzzle Cast Puzzle - Dial (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":29,"list":"products","quantity":1,"id":"515002","name":"Huzzle Cast Puzzle - Diamond (level 1)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":30,"list":"products","quantity":1,"id":"515043","name":"Huzzle Cast Puzzle - Dice (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":31,"list":"products","quantity":1,"id":"515034","name":"Huzzle Cast Puzzle - Dolce (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":32,"list":"products","quantity":1,"id":"515057","name":"Huzzle Cast Puzzle - Donuts (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":33,"list":"products","quantity":1,"id":"515016","name":"Huzzle Cast Puzzle - Dot (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":34,"list":"products","quantity":1,"id":"515088","name":"Huzzle Cast Puzzle - Duet (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":35,"list":"products","quantity":1,"id":"515081","name":"Huzzle Cast Puzzle - Elk (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":36,"list":"products","quantity":1,"id":"515089","name":"Huzzle Cast Puzzle - Equa (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":37,"list":"products","quantity":1,"id":"515004","name":"Huzzle Cast Puzzle - Flag (level 1)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":38,"list":"products","quantity":1,"id":"515038","name":"Huzzle Cast Puzzle - G&G (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":39,"list":"products","quantity":1,"id":"515039","name":"Huzzle Cast Puzzle - Galaxy (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":40,"list":"products","quantity":1,"id":"515093","name":"Huzzle Cast Puzzle - H&H (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":41,"list":"products","quantity":1,"id":"515015","name":"Huzzle Cast Puzzle - Harmony (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":42,"list":"products","quantity":1,"id":"515040","name":"Huzzle Cast Puzzle - Hashtag (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":43,"list":"products","quantity":1,"id":"515052","name":"Huzzle Cast Puzzle - Heart (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":44,"list":"products","quantity":1,"id":"515091","name":"Huzzle Cast Puzzle - Helix (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":45,"list":"products","quantity":1,"id":"515062","name":"Huzzle Cast Puzzle - Hexagon (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":46,"list":"products","quantity":1,"id":"515013","name":"Huzzle Cast Puzzle - Hook (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":47,"list":"products","quantity":1,"id":"515011","name":"Huzzle Cast Puzzle - Horse (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":48,"list":"products","quantity":1,"id":"515119","name":"Huzzle Cast Puzzle - Hourglass (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":49,"list":"products","quantity":1,"id":"515012","name":"Huzzle Cast Puzzle - Key II (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":50,"list":"products","quantity":1,"id":"515061","name":"Huzzle Cast Puzzle - Keyhole (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":51,"list":"products","quantity":1,"id":"515054","name":"Huzzle Cast Puzzle - L'Oeuf (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":52,"list":"products","quantity":1,"id":"515001","name":"Huzzle Cast Puzzle - Loop (level 1)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":53,"list":"products","quantity":1,"id":"515005","name":"Huzzle Cast Puzzle - Love (level 1)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":54,"list":"products","quantity":1,"id":"515090","name":"Huzzle Cast Puzzle - Marble (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":55,"list":"products","quantity":1,"id":"515063","name":"Huzzle Cast Puzzle - Mobius (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":56,"list":"products","quantity":1,"id":"515112","name":"Huzzle Cast Puzzle - News (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":57,"list":"products","quantity":1,"id":"515087","name":"Huzzle Cast Puzzle - Radix (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":58,"list":"products","quantity":1,"id":"515094","name":"Huzzle Cast Puzzle - Rattle (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":59,"list":"products","quantity":1,"id":"515051","name":"Huzzle Cast Puzzle - Ring (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":60,"list":"products","quantity":1,"id":"515086","name":"Huzzle Cast Puzzle - Ring II (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":61,"list":"products","quantity":1,"id":"515120","name":"Huzzle Cast Puzzle - Rotor (level 6)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":62,"list":"products","quantity":1,"id":"515032","name":"Huzzle Cast Puzzle - S&S (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":63,"list":"products","quantity":1,"id":"515042","name":"Huzzle Cast Puzzle - Slider (Level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":64,"list":"products","quantity":1,"id":"515017","name":"Huzzle Cast Puzzle - Snow (level 2)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":65,"list":"products","quantity":1,"id":"515092","name":"Huzzle Cast Puzzle - Square (level 5)","price":"11.53","brand":"Huzzle","category":"Breinbrekers"},{"position":66,"list":"products","quantity":1,"id":"515031","name":"Huzzle Cast Puzzle - Star (level 3)","price":"9.88","brand":"Huzzle","category":"Breinbrekers"},{"position":67,"list":"products","quantity":1,"id":"515059","name":"Huzzle Cast Puzzle - Twist (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":68,"list":"products","quantity":1,"id":"515060","name":"Huzzle Cast Puzzle - U&U (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":69,"list":"products","quantity":1,"id":"515067","name":"Huzzle Cast Puzzle - Valve (level 4)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"},{"position":70,"list":"products","quantity":1,"id":"515036","name":"Huzzle Cast Puzzle - Violon (level 3)","price":"10.70","brand":"Huzzle","category":"Breinbrekers"}]}
});

</script>
<!-- End Google Tag Manager -->
<script type="text/javascript">
(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
})(window,document,'script','//www.google-analytics.com/analytics.js','ga');  
ga('create', 'UA-19294223-1', 'auto');
ga('set', 'anonymizeIp', true); 
ga('set', 'forceSSL', true); 
ga('send', 'pageview'); 
</script>
<title>
	Zoekopdracht: huzzle
</title><meta name="description" content="Zoekopdracht: huzzle" /></head>
<body id="MasterBody" class="preload nl page-search page-overview-products user-is-not-logged-in">
    
    <!-- Google Tag Manager (noscript) -->
<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WFP3PZW" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<!-- End Google Tag Manager (noscript) -->

    
    
    
    <div class="shopholder">

        <!-- REGEL -1-->
        

        
            <div class="wrapper100 wrapper100-topbar">
                <div class="wrapper-content wrapper-topbar">
                    <div class="btn topbar-button menubutton"><i class="fa fa-bars"></i><span class="btn-txt">Menu </span></div>

                    <form name='search'
action='javascript:redirectToSelectedAutocompleteSearch();'
class='search'>
<input 
required='required' 
maxlength='150' 
value='huzzle' 
name='txtSearch' 
onfocus='autocompleteOnFocus(this, ulSearchResults_209282, true)'
onfocusout='autocompleteOnFocusOut()'
onkeyup='AutocompleteSearch(this.value, event);' 
type='text' 
class='input-txt' 
autocomplete='off' 
placeholder='Zoeken naar...'/>
<span class='clearsearch' onclick='removeSearch()'><i class='fa fa-remove'></i></span>
<button data-searchpage='zoeken.html' aria-label='Zoeken naar...' type='submit' onclick='SubmitSearch(this)' class='button topbar-searchbutton searchbutton'><i class='fa fa-search'></i></button>
<div class='autocomplete-holder'>
<div class='inner-autocomplete-holder'>
<ul id='ulSearchResults_209282'></ul>
</div>
</div>
</form>
<div class='searchblock'></div>


                    <div class="topbar-logo">
                        <a href='/' class='shoplogo' title='Spellenrijk.nl - Online Spellenwinkel'>
<img src='/styles/clients/spellenrijk-2020/img/moblogo.svg' alt='Spellenrijk.nl - Online Spellenwinkel'/>
</a>

                    </div>

                    <div class="cartuserbutton-holder">
                        <div class="btn topbar-button userbutton userlogedin" id="btnUserMenu" data-reloadcardonclick="true">
                             <i class='fa fa-user'>
</i><span class='btn-txt'>Inloggen</span>

                        </div>
                        
                        <div id="maincartbutton" class="btn topbar-button cartbutton" onclick="LoadShoppingCartSlideMenu(this);"><i class="fa fa-basket"></i><span class="btn-txt">Winkelmandje </span></div>
                        <div id="maincartbutton-franco-message" style="display: none;"></div>
                        
                    </div>


                    
                </div>
            </div>
        

        


        <!-- REGEL 0-->
        <div class='wrapper100 wrapper100-regel0'>
<div class='blockcontainer wrapper-content wrapper-regel0'>
<div id="websiteblok16" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 pagecfg key-next-regel0">
<div id="websitecontentblok104" class="box pcw100 pcs0010 tabw100 tabs0010 mobhide element">
<nav id="menubar104" class="box pcw100 pcs0010 tabw100 tabs0010 mobhide menubar" ><ul class="menubar-holder2-v1 "><li class='nav-main '><a class='nav-main' href='/'><i class="fas fa-home"></i></a></li><li class='nav-main '><a class='nav-main' href='/categorie/58/gezelschapsspellen.html'>Spellen</a><div class='nav-subholder'><ul class='nav-sub1 '><li class='nav-sub1 '><a class='nav-sub1' href='https://www.spellenrijk.nl/categorie/158/bordspellen.html'>Bordspellen</a><ul class='nav-sub2 '><li class='nav-sub2 '><a class='nav-sub2' href='/top-10-bordspellen/'>Top 10 Bordspellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/158/bordspellen.html?ft12=Best-verkocht'>Best verkocht</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/276/cooperatieve-spellen.html'>Coöperatieve spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/familiespellen/'>Familiespellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/58/gezelschapsspellen.html?ft14=Escape-Room-spel'>Escape Room spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/products.aspx?ft14=Strategisch-spel&limit=filtergrp'>Strategische spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/144/trivia-spellen.html'>Trivia spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/products.aspx?ft14=Oud-Hollands-spel'>Oud Hollandse spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/spellen-voor-2-spelers/'>Spellen voor 2 spelers</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/223/spelkleden.html'>Spelkleden</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/45/reisspellen.html'>Reisspellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/309/erotische-spellen.html'>Erotische spellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/313/dartborden-dartpijlen.html'>Dartborden & Dartpijlen</a></li></ul></li><li class='nav-sub1 '><a class='nav-sub1' href='https://www.spellenrijk.nl/categorie/146/party-spellen.html'>Partyspellen</a><ul class='nav-sub2 '><li class='nav-sub2 '><a class='nav-sub2' href='/top-10-partyspellen/'>Top 10 Partyspellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/146/party-spellen.html?ft4=Nederlands'>Nederlandse Partyspellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/146/party-spellen.html?ft4=Engels'>Engelse Partyspellen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/146/party-spellen.html?ft12=Best-verkocht'>Best verkocht</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/zoeken.html?s=Cards%20Against%20Humanity'>Cards Against Humanity</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/zoeken.html?s
a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/182/mozaiek.html'>Mozaiek</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/merk/153/ses-creative.html'>SES Creative</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/zoeken.html?s=slijm'>Slijm maken</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/185/schrijfwaren.html'>Schrijfwaren</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/247/binnenspeelzand.html'>Binnenspeelzand</a></li></ul></li><li class='nav-sub1 '><a class='nav-sub1' href='/categorie/88/hobby-artikelen.html?grp=118%2c255%2c248%2c303%2c318&limit=filtergrp'>Speelgoed</a><ul class='nav-sub2 '><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/255/jongleren.html'>Jongleren</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/118/goochelen.html'>Goochelen</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/categorie/248/tangle.html'>Tangles</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/fidget-slug/'>Fidget Slug</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/pokemon-knuffels/'>Pokemon Knuffels</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/funko-pop/'>Funko Pop</a></li><li class='nav-sub2 '><a class='nav-sub2' href='https://www.spellenrijk.nl/pokemon-knuffels/'>Super Mario Knuffels</a></li></ul></li><li class='nav-sub1 '><a class='nav-sub1' href='/categorie/88/hobby-artikelen.html?br=153%2c323%2c47%2c234%2c477%2c50%2c346&limit=filterbr'>Populaire merken</a><ul class='nav-sub2 '><li class='nav-sub2 '><a class='nav-sub2' href='/merk/153/ses-creative.html'>SES Creative</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/merk/477/creall.html'>Creall</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/merk/234/buki.html'>Buki</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/88/hobby-artikelen.html?br=47&limit=filterbr'>Ravensburger</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/zoeken.html?s=spektro'>Spektro</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/categorie/88/hobby-artikelen.html?br=50&limit=filterbr'>Clementoni</a></li><li class='nav-sub2 '><a class='nav-sub2' href='/merk/323/crayon-rocks.html'>Crayon Rocks</a></li></ul></li></ul></div></li><li class='nav-main '><a class='nav-main' href='/merken.html'>Merken</a></li><li class='nav-main '><a class='nav-main' href='/contact.html'>Contact</a></li><li class='nav-main '><a class='nav-main' href='/sale/'>Sale</a></li></ul></nav>
</div>
</div>
</div>
</div>


        
            <div class="wrapper100 wrapper100-logobar">
                <div class="wrapper-content wrapper-logobar">
                    <div class="logoholder">
                        <a href='/' class='shoplogo' title='Spellenrijk.nl - Online Spellenwinkel'>
<img src='/styles/clients/spellenrijk-2020/img/logo.png' alt='Spellenrijk.nl - Online Spellenwinkel'/>
</a>

                    </div>
                    <div class='blockcontainer uspholder'>
<div id="websiteblok21" class="box pcw80 pcs0010 tabw80 tabs0010 mobhide pagecfg key-next-logobar">
<div id="websitecontentblok138" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 header-usp element">
<div id="cmscontentblok222" class="box pcw30 pcs0010 tabw45 tabs0010 mobhide cmscfg">

<i class="fa fa-calendar-check-o"></i>
<div><span class="usptxt">Ma-Vr voor 18:00 besteld is morgen in huis</span></div>
</div>
<div id="cmscontentblok223" class="box pcw25 pcs0020 tabw35 tabs0020 mobhide cmscfg">

<i class="fa fa-truck"></i>
<div><span class="usptxt">Gratis verzending in NL vanaf € 50</span></div>
</div>
<div id="cmscontentblok224" class="box pcw25 pcs0030 tabhide mobhide cmscfg">

<i class="fa fa-check"></i>
<div><span class="usptxt">+10.000 artikelen in voorraad</span></div>
</div>
<div id="cmscontentblok196" class="box pcw20 pcs0050 tabw20 tabs0050 mobhide cmscfg">

<a title="Thuiswinkel waarborg" href="https://www.thuiswinkel.org/leden/spellenrijk.nl/certificaat" target="_blank"><img alt="Thuiswinkel waarborg" src="https://content17.logic4server.nl/clientdata/spellenrijk/images/Thuiswinkel_Waarborg_Kleur_Horizontaal-35pixels_6276262594339.png" /></a>
</div>
</div>
<div id="websitecontentblok137" class="box pcw0 pcs0100 tabw0 tabs0100 mobhide searchcls element">
<div id="zoektekstboxcontentblok137" class="box pcw100 pcs1 tabw100 tabs1 mobhide searchcfg">
<form name='search'
action='javascript:redirectToSelectedAutocompleteSearch();'
class='search'>
<input 
required='required' 
maxlength='150' 
value='huzzle' 
name='txtSearch' 
onfocus='autocompleteOnFocus(this, ulSearchResults_209284, false)'
onfocusout='autocompleteOnFocusOut()'
onkeyup='AutocompleteSearch(this.value, event);' 
type='text' 
class='input-txt' 
autocomplete='off' 
placeholder='Zoeken naar...'/>
<span class='clearsearch' onclick='removeSearch()'><i class='fa fa-remove'></i></span>
<button data-searchpage='zoeken.html' aria-label='Zoeken naar...' type='submit' onclick='SubmitSearch(this)' class='button topbar-searchbutton searchbutton'><i class='fa fa-search'></i></button>
<div class='autocomplete-holder bodysearch'>
<div class='inner-autocomplete-holder'>
<ul id='ulSearchResults_209284'></ul>
</div>
</div>
</form>
</div>
</div>
</div>
</div>

                </div>
            </div>
        

        

        <!-- REGEL 1-->
        

        <!-- REGEL 2-->
        

        <!-- REGEL 3-->
        <div class='wrapper100 wrapper100-regel3'>
<div class='blockcontainer wrapper-content wrapper-regel3'>
</div>
</div>


        <!-- REGEL 4-->
        

        <!-- REGEL 5-->
        

        <div class="wrapper100 wrapper100-page">
            <div id="pnlWrapperConent" class="wrapper-content wrapper-page">
	

                
                <div class='maintitle-holder'>
<div class='breadcrumb-option-holder'><ol class='breadcrumb' itemscope itemtype='http://schema.org/BreadcrumbList'>
<li itemprop='itemListElement' itemscope itemtype='http://schema.org/ListItem'>
<a itemprop='item' href='/'><span itemprop='name'>Home</span></a>
<meta itemprop='position' content='1' />
</li>
</ol>

</div>
<link itemprop='url' href='https://www.spellenrijk.nl/zoeken.html?s=huzzle'>
<h1 id='pageheadertitle'>Zoekopdracht: huzzle</h1>
</div>


                

    <form method="post" action="./zoeken.html?s=huzzle" id="form1">
	<div class="aspNetHidden">
	<input type="hidden" name="__EVENTTARGET" id="__EVENTTARGET" value="" />
	<input type="hidden" name="__EVENTARGUMENT" id="__EVENTARGUMENT" value="" />
	<input type="hidden" name="__LASTFOCUS" id="__LASTFOCUS" value="" />
	<input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />
	</div>
	
<script type="text/javascript">
//<![CDATA[
var theForm = document.forms['form1'];
	if (!theForm) {
    theForm = document.form1;
}
	function __doPostBack(eventTarget, eventArgument) {
    if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
        theForm.__EVENTTARGET.value = eventTarget;
        theForm.__EVENTARGUMENT.value = eventArgument;
        theForm.submit();
    }
}
	//]]>
</script>


	
<script src="/ScriptResource.axd?d=8gY6fdQfdm4bB1JrjR7MKJYuhX9gDb_VQReqI75e5lzpU6wK6pdcJNOPHzqCmkKitJLs0yZeSZ7gdYSXF_Sx07WBRbJJ-M9IV9n4CEC8THbo5b-kQeZyUtbAtvsP8BWIeZ2RebLSWC3FofmCLP-AHTWCTrG1OogYqP3Dj2UiS935lX47V39IBn1XR0sxng8bNronNvhsOJj0fN7RHH08dhZfg-Hvzv3T5o3SZBey-65oxkG5z8cm2KYbq0fOpyB362B5isvG-pmhHD2WyfjgfWgX-Pa5ai2i8Kao3a0I6r-NKKijgg8Lav1gJtF5416TumE38-7i-5PrRiFmr1Toq_ru8keQCjISL6USad2lock1" type="text/javascript"></script>
	<div class="aspNetHidden">

		<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="AA98EE0D" />
		<input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="..." />
	</div>
        <script type="text/javascript">
//<![CDATA[
Sys.WebForms.PageRequestManager._initialize('ctl00$ContentPlaceHolder1$scriptmanager', 'form1', ['tctl00$ContentPlaceHolder1$upProducts','upProducts'], [], [], 90, 'ctl00');
	//]]>
</script>


        <input type="hidden" name="ctl00$ContentPlaceHolder1$hdnBestellistId" id="ContentPlaceHolder1_hdnBestellistId" />
        <div id="upProducts">
		
                <script>var currentActiveLimits = [];</script>
                <div class="productlistfilter productlistfilter20">
                    <div id="innerproductlistfilter" class="innerproductlistfilter">
                        
                        <div class='defaultfilter pricefilter'>
<h5>Prijs</h5>
<div class='defaultsliderholder pricesliderholder'><div class='pricefilter-slider'></div></div>
<table>
<tr>
<td>
<span>€</span>
<input data-lastvalue='0' data-minvalue='0' min='0' data-filtername='pricefrom' data-decimal='false' type='number' class='input-white pricefilter-startAmount pricefilter-inputtxt' onblur='FilterTextboxLeave(this)' value='0' />
</td>
<td>tot</td>
<td>
<span>€</span>
<input data-lastvalue='15' data-maxvalue='15' min='0'  data-filtername='priceto' data-decimal='false' type='number' class='input-white pricefilter-endAmount pricefilter-inputtxt' onblur='FilterTextboxLeave(this)' value='15' />
</td>
</tr>
</table>
<span class='filtercommit'>
<i class='fa fa-chevron-right'></i>
Prijs filteren
</span>
</div>
<div class='listfilter'>
<h5>Voorraad
<div id='ShowFilterInfo' class='filterInfoBtn'><i class='fa fa-info-circle'></i>
<div id='AdditionalFilterInfo'><h5>Voorraad</h5>Toon alleen producten die daadwerkelijk in voorraad zijn bij ons.</div>
</div>
</h5>
<ul id='filtercheckboxstockfrom'>
<li>
<input type='checkbox' autocomplete='off' id='checkboxstockfrom0'  onclick="LoadAjaxPage('?s=huzzle&checkboxstockfrom=0',true);"/>
<label for='checkboxstockfrom0'>
Alleen producten op voorraad tonen
</label>
</li>
</ul>
</div>
<div class='listfilter'>
<h5>Status
</h5>
<ul id='filterft12'>
<li>
<input type='checkbox' autocomplete='off' id='ft12Best-verkocht'  onclick="LoadAjaxPage('?s=huzzle&ft12=Best-verkocht',true);"/>
<label for='ft12Best-verkocht'>
Best verkocht (55)
</label>
</li>
<li>
<input type='checkbox' autocomplete='off' id='ft12Nieuw-in-collectie'  onclick="LoadAjaxPage('?s=huzzle&ft12=Nieuw-in-collectie',true);"/>
<label for='ft12Nieuw-in-collectie'>
Nieuw in collectie (1)
</label>
</li>
</ul>
</div>
<div class='listfilter'>
<h5>Leeftijd
</h5>
<ul id='filterft1'>
<li>
<input type='checkbox' autocomplete='off' id='ft16---9-jaar'  onclick="LoadAjaxPage('?s=huzzle&ft1=6---9-jaar',true);"/>
<label for='ft16---9-jaar'>
6 - 9 jaar (68)
</label>
</li>
<li>
<input type='checkbox' autocomplete='off' id='ft19---12-jaar'  onclick="LoadAjaxPage('?s=huzzle&ft1=9---12-jaar',true);"/>
<label for='ft19---12-jaar'>
9 - 12 jaar (68)
</label>
</li>
<li>
<input type='checkbox' autocomplete='off' id='ft112---18-jaar'  onclick="LoadAjaxPage('?s=huzzle&ft1=12---18-jaar',true);"/>
<label for='ft112---18-jaar'>
12 - 18 jaar (68)
</label>
</li>
<li>
<input type='checkbox' autocomplete='off' id='ft1Vanaf-18-jaar'  onclick="LoadAjaxPage('?s=huzzle&ft1=Vanaf-18-jaar',true);"/>
<label for='ft1Vanaf-18-jaar'>
Vanaf 18 jaar (68)
</label>
</li>
</ul>
</div>
<button class="filterbox-filter-btn pchide tabhide" onclick="toggleAllmenu();">Toon 71 producten</button>

                    </div>

                    
                </div>

                <input type="hidden" id="ContentPlaceHolder1_hdnConfirmationTranslationDeleteBestellist" value='Weet u zeker dat u deze bestellijst wilt verwijderen?' />
                <div class="productlist-mainholder">

                    <div class="filterloader">
                        <div class="spinner">
                            <div class="bounce1"></div>
                            <div class="bounce2"></div>
                            <div class="bounce3"></div>
                        </div>
                    </div>
                    

                    <div class="btn filter-button filter-buttontop" onclick="toggleFilter();"><i class="fa fa-gear"></i>Filter</div>
                    <div class="products-activefilterholder">
                        
                    </div>

                    <div id="ContentPlaceHolder1_pnlFilterBarTop" class="products-pagholder topproducts-pagholder">
			
                        <div class="products-paginnerholder">

                            <div class="paginginnerholder">
                                <span id="ContentPlaceHolder1_lblPaginaVanTop" class="paginavan"></span>
                                
                            </div>

                            <div class="products-amountoption">
                                Weergave:

                                <label class="nicedropdown">
                                    <select name="ctl00$ContentPlaceHolder1$drpdnMaxItemsPerPage" onchange="javascript:setTimeout(&#39;__doPostBack(\&#39;ctl00$ContentPlaceHolder1$drpdnMaxItemsPerPage\&#39;,\&#39;\&#39;)&#39;, 0)" id="ctl00_ContentPlaceHolder1_drpdnMaxItemsPerPage">
				<option value="24">24</option>
				<option value="48">48</option>
				<option selected="selected" value="96">96</option>

			</select>
                                </label>

                                <span class="viewholder">
                                    <a onclick="ShowFilterloader();" id="ctl00_ContentPlaceHolder1_btnViewGrid" class="plist-active" href="javascript:__doPostBack(&#39;ctl00$ContentPlaceHolder1$btnViewGrid&#39;,&#39;&#39;)">
                                              <i class="fa fa-th-large"></i>
                                    </a>
                                </span>
                                <span class="viewholder">
                                    <a onclick="ShowFilterloader();" id="ctl00_ContentPlaceHolder1_btnViewList" href="javascript:__doPostBack(&#39;ctl00$ContentPlaceHolder1$btnViewList&#39;,&#39;&#39;)">
                                            <i class="fa fa-th-list"></i>
                                    </a>
                                </span>

                            </div>
                            <div id="ContentPlaceHolder1_pnlSorting" class="products-sortoption">
				
                                Sorteren:
                                <label class="nicedropdown">
html' onclick="AddToCart(this,true);">
<i class='fa fa-basket'></i>
</span>

</div>
</div>
<div class='productlist-vergelijkholder'>
<input type='checkbox' class='comparecheckbox' id='chkCompare_32714' data-productid='32714'onclick='ToggleProductCompare(32714);' autocomplete='off'/><label for='chkCompare_32714'>Vergelijken</label>
</div>
</div>
</div>
</div>
<div class='productlistholder productlist25'>
<div id='pid-31321' class='innerproductlist' data-qty='6,0000' data-productprice='10.70' data-productcode='515036' data-productname='Huzzle Cast Puzzle - Violon (level 3)' data-productbrand='Huzzle' data-productbarcode='5407005150368'>
<a href='https://www.spellenrijk.nl/artikel/31321/huzzle-cast-puzzle-violon-level-3.html' title='Huzzle Cast Puzzle - Violon (level 3)' class='productlist-imgholder gtm-product-impression'>
<img src="/img/placeholder.png" data-src="https://www.spellenrijk.nl/resize/914x1200_8813763197453.jpg/250/250/True/huzzle-cast-puzzle-violon-level-3.jpg" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Huzzle Cast Puzzle - Violon (level 3)" class="lazyload"/>
</a>
<div class='productlist-topfx'>
<h3 class='productlist-title gtm-product-impression'>
<a href='https://www.spellenrijk.nl/artikel/31321/huzzle-cast-puzzle-violon-level-3.html' title='Huzzle Cast Puzzle - Violon (level 3)'>Huzzle Cast Puzzle - Violon (level 3)</a>
</h3>
<span class='productlist-stock stock-green'>Op werkdagen voor 18:00 besteld is morgen in huis</span>
</div>
<div class='productlist-bottomfx'>
<span class='productlist-oldprice'>
</span>
<div class='productlist-priceholder'>
<span class='productlist-oldpricesub'>

</span>
<span class='productlist-price'>
<span class='product-price-currency'>€ </span><span class='product-price-amount'>12,95</span>
</span>

</div>
<div class='product-buyinfoholder product-buyholderonly'>
<div class='productlist-buyholder' title='Toevoegen aan winkelmandje'>
<span  data-productid='31321' data-productcode='515036' data-productname='Huzzle Cast Puzzle - Violon (level 3)' data-productprice='10.70' data-productbrand='Huzzle' data-qty='1' data-url='https://www.spellenrijk.nl/artikel/31321/huzzle-cast-puzzle-violon-level-3.html' onclick="AddToCart(this,true);">
<i class='fa fa-basket'></i>
</span>

</div>
</div>
<div class='productlist-vergelijkholder'>
<input type='checkbox' class='comparecheckbox' id='chkCompare_31321' data-productid='31321'onclick='ToggleProductCompare(31321);' autocomplete='off'/><label for='chkCompare_31321'>Vergelijken</label>
</div>
</div>
</div>
</div>


                    <div id="price-calculator-popup" style="display: none">
                        <!-- JESSE HIER VERDER (popup) !-->
                        Welke lengte heeft u nodig?
                        <br />
                        <input id="txt-popup-qty-m" value="0" type="number" step="1" min="0"
                            onmouseup="reCalculatePricePopup()"
                            onkeyup="reCalculatePricePopup()" />
                        meter
                        <input id="txt-popup-qty-cm" value="0" type="number" step="10" min="0" max="90" oninput="maxLengthCheck(this)"
                            onmouseup="reCalculatePricePopup()"
                            onkeyup="reCalculatePricePopup()" />
                        centimeter / <span id="spn-popup-unit-length"></span>
                        <br />

                        Dan moet u <span id="spn-popup-product-count">0</span> stuks bestellen<br />
                        Voor <span id="spn-popup-price">0</span> euro incl. BTW
                        <br />
                        <button id="btn-popup-fill-qty" type="button" onclick="fillQtyBoxWithNumber()">Invullen</button>
                    </div>

                    <div id="ContentPlaceHolder1_pnlFilterBarBottom" class="products-pagholder bottomproducts-pagholder">
			
                        <div class="products-paginnerholder">


                            <div class="products-amountoption">
                                Weergave:
                                <label class="nicedropdown">
                                    <select name="ctl00$ContentPlaceHolder1$drpdnMaxItemsPerPageBottom" onchange="javascript:setTimeout(&#39;__doPostBack(\&#39;ctl00$ContentPlaceHolder1$drpdnMaxItemsPerPageBottom\&#39;,\&#39;\&#39;)&#39;, 0)" id="ctl00_ContentPlaceHolder1_drpdnMaxItemsPerPageBottom">
				<option value="24">24</option>
				<option value="48">48</option>
				<option selected="selected" value="96">96</option>

			</select>
                                </label>

                                <span class="viewholder">
                                    <a id="ctl00_ContentPlaceHolder1_btnViewGrid2" class="plist-active" href="javascript:__doPostBack(&#39;ctl00$ContentPlaceHolder1$btnViewGrid2&#39;,&#39;&#39;)">
                                              <i class="fa fa-th-large"></i>
                                    </a>
                                </span>
                                <span class="viewholder">
                                    <a id="ctl00_ContentPlaceHolder1_btnViewList2" href="javascript:__doPostBack(&#39;ctl00$ContentPlaceHolder1$btnViewList2&#39;,&#39;&#39;)">
                                            <i class="fa fa-th-list"></i>
                                    </a>
                                </span>
                            </div>

                            <div id="ContentPlaceHolder1_pnlSortingBottom" class="products-sortoption">
				
                                Sorteren:
                                <label class="nicedropdown">
                                    <select name="ctl00$ContentPlaceHolder1$drpdnSortingBottom" onchange="javascript:setTimeout(&#39;__doPostBack(\&#39;ctl00$ContentPlaceHolder1$drpdnSortingBottom\&#39;,\&#39;\&#39;)&#39;, 0)" id="ctl00_ContentPlaceHolder1_drpdnSortingBottom">
					<option selected="selected" value="RELEVANTIE">Relevantie</option>
					<option value="NIEUWAFLOPEND">Nieuwste bovenaan</option>
					<option value="NIEUWOPLOPEND">Oudste bovenaan</option>
					<option value="ALFABETISCH">Alfabetisch</option>
					<option value="PRIJSOPLOPEND">Prijs oplopend</option>
					<option value="PRIJSAFLOPEND">Prijs aflopend</option>

				</select>
                                </label>
                            
			</div>
                            <div class="paginginnerholder">
                                <span id="ContentPlaceHolder1_lblPaginaVanBottom" class="paginavan"></span>
                                
                            </div>

                            <div class="btn filter-button" onclick="toggleFilter();"><i class="fa fa-gear"></i>Filter</div>
                        </div>
                    
		</div>
                    

                    <div class='vergelijkholder-float' style='display:none'>
<span class='compare-button title h2'>0 geselecteerde artikelen</span>
<a id='btnVergelijk' class='btn vergelijk-button' href='#'>Bekijk vergelijking</a>
<a id='btnClearVergelijk' class='btn vergelijkremove-button' href='javascript:ClearProductCompare();'><i class='fa fa-remove'></i></a>
</div>

                </div>
            
	</div>
    </form>
    <script type="text/javascript">
        function ChangeQtyStd(qty, otherqty, calcamount, stdamount, stdunit) {
            var value = parseFloat(qty);
            var stdQty = parseFloat(stdamount.innerHTML);
            var total = Math.round(((value / stdQty) + 0.00001) * 100) / 100;
            otherqty.value = total

            var unit = stdunit.innerHTML;
            calcamount.innerHTML = "(" + total.toString() + " " + unit + ")";
        }

        function ChangeQtyUnit(qty, otherqty, calcamount, stdamount, stdunit) {
            var value = parseFloat(qty);
            var stdQty = parseFloat(stdamount.innerHTML);
            var unit = stdunit.innerHTML;

            var productCount = Math.ceil(value * stdQty);
            otherqty.value = productCount.toString();
            var total = (Math.round(((productCount / stdQty) + 0.00001) * 100) / 100).toString();
            calcamount.innerHTML = "(" + total + " " + unit + ")";
        }

        function ChangeQty(qty, productId, fieldId) {
            clearTimeout(VeranderAantalTimer);
            VeranderAantalTimer = setTimeout(function () {
                $.ajax({
                    type: "POST",
                    url: "/webfunctions/LimitBuyQuantity.ashx",
                    data: {
                        request: "QtyLimitProduct",
                        qty: qty,
                        productId: productId,
                    },
                    success: function (response) {
                        fieldId = '#' + fieldId;
                        $(fieldId).val(response);
                    }
                });
            }, VeranderAantalDelay);
        }
    </script>

                
            
</div>
        </div>

        <div class='wrapper100 wrapper100-lastviewedproductlist'>
<div class='blockcontainer wrapper-content wrapper-lastviewedproductlist'>
<div id="websiteblok26" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 pagecfg key-next-lastviewedproductlist">
<div id="websitecontentblok103" class="box pcw100 pcs0999 tabw100 tabs0999 mobw100 mobs0999 element lastviewed-artikelen-element htmllazyload" data-function='getLastViewedProductList'>
</div>
</div>
</div>
</div>


        <div class='wrapper100 wrapper100-subfooter'>
<div class='blockcontainer wrapper-content wrapper-subfooter'>
</div>
</div>
<div class='wrapper100 wrapper100-footer'>
<div class='blockcontainer wrapper-content wrapper-footer'>
<div id="websiteblok20" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 pagecfg key-next-footer">
<div id="websitecontentblok112" class="box pcw100 pcs0001 tabw100 tabs0001 mobw100 mobs0001 niewsbrief-footer element">
<div id="cmscontentblok185" class="box pcw100 pcs0001 tabw100 tabs0001 mobw100 mobs0001 cmscfg nieuwsbrief">

<form name="nieuwsbrief" method="post" action="/webfunctions/nieuwsbrief.ashx" onsubmit="return false;">
<div id="divNieuwsbriefError"></div>
<div class="newsinnercontentbox">
<h4>Nieuwsbrief</h4>
<p >Schrijf je nu gratis in voor onze nieuwsbrief en blijf op de hoogte van de nieuwste spellen en puzzels. Daarnaast ontvang je ook leuke acties en aanbiedingen in je mailbox. We sturen maximaal 2 keer per maand een nieuwsbrief, dus wat houdt je nog tegen? Vul nu hieronder je e-mailadres in en druk op aanmelden.</p>
<input id="txtNieuwsbrief_Email" name="nieuwsbrief_email" class="input-white news-inputtxt" placeholder="E-mailadres" type="email" maxlength="250" pattern="[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,4}$" title="Ongeldig e-mailadres" required="required">
<span class="bumbli-wrap bumbli-sol"><input type="text" name="full-name-city" class="bumblinumber" placeholder="Full name and city"></span>
<input type="submit" class="btn news-button" value="Aanmelden" onclick="SubmitNieuwsbrief(this)">
</div>
</form>
</div>
</div>
<div id="websitecontentblok111" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 element">
<div id="cmscontentblok175" class="box pcw25 pcs0010 tabw50 tabs0010 mobw100 mobs0010 linkcfg">
<div class='contentbox linkinnercontentbox'>
<h4 >Klantenservice</h4>
<ul>
<li><a href='/i/algemene-voorwaarden.html' title='Algemene voorwaarden'><i class='fa fa-chevron-right'></i>Algemene voorwaarden</a></li>
<li><a href='/i/privacy.html' title='Privacy'><i class='fa fa-chevron-right'></i>Privacy</a></li>
<li><a href='/i/retouren.html' title='Retouren'><i class='fa fa-chevron-right'></i>Retouren</a></li>
<li><a href='/i/vragen.html' title='Vragen'><i class='fa fa-chevron-right'></i>Vragen</a></li>
</ul>
</div>
</div>
<div id="cmscontentblok229" class="box pcw25 pcs0010 tabw50 tabs0010 mobw100 mobs0010 linkcfg">
<div class='contentbox linkinnercontentbox'>
<h4 >Over SpellenRijk</h4>
<ul>
<li><a href='/products.aspx' title='Ons assortiment'><i class='fa fa-chevron-right'></i>Ons assortiment</a></li>
<li><a href='/i/bedrijfs-informatie.html' title='Bedrijfsinformatie'><i class='fa fa-chevron-right'></i>Bedrijfsinformatie</a></li>
<li><a href='/artikel/26758/spellenrijk-cadeaubon.html' title='Cadeaubonnen'><i class='fa fa-chevron-right'></i>Cadeaubonnen</a></li>
</ul>
</div>
</div>
<div id="cmscontentblok184" class="box pcw25 pcs0020 tabw50 tabs0020 mobw100 mobs0020 cmscfg">

<div class="cmsinnercontentbox adresfooter" itemtype="http://schema.org/Organization" itemscope="">
<header>
<h4 itemprop="name">Spellenrijk B.V.</h4>

</header>
<p>
	<i class="fa fa-map-marker"></i>
	<span class="adrestxt">
		<span itemtype="http://schema.org/PostalAddress" itemscope="" itemprop="address">
			<span itemprop="streetAddress">Zaagstraat 1-13</span>
			<br />
			<span itemprop="postalCode">7556 MX Hengelo (NL)</span> 
		</span>
	</span>

	<i class="fa fa-link"></i>
	<span class="adrestxt">
		<a title="Spellenrijk B.V." href="https://www.spellenrijk.nl" target="_blank" itemprop="url">www.spellenrijk.nl</a>
	</span> 

	<i class="fa fa-phone"></i>
	<span class="adrestxt">
		<a title="Bel ons" href="tel:0742500238" target="_blank" itemprop="telephone">074-2500238</a>
	</span> 

	<i class="fa fa-envelope"></i>
	<span class="adrestxt">
		<a title="Mail ons" href="mailto:info@spellenrijk.nl" target="_blank" itemprop="email">info@spellenrijk.nl</a>
	</span> 
</p>
</div>

</div>
<div id="cmscontentblok238" class="box pcw25 pcs0020 tabw50 tabs0020 mobw100 mobs0020 cmscfg">

<div class="cmsinnercontentbox socialfooter" itemtype="http://schema.org/Organization" itemscope="">
<header>
<h4 itemprop="name">Volg ons</h4>

</header>
<p>
	<span class="socialtxt">
		<a title="Facebook" href="https://www.facebook.com/spellenrijk" target="_blank" rel="nofollow" itemprop="email"><i class="fa  fa-facebook-square"></i></a>
		<a title="Twitter" href="https://www.twitter.com/spellenrijk" target="_blank" rel="nofollow" itemprop="email"><i class="fa  fa-twitter-square"></i></a>
		<a title="Youtube" href="https://www.youtube.com/spellenrijk" target="_blank" rel="nofollow" itemprop="email"><i class="fa  fa-youtube-square"></i></a>
		<a title="Instagram" href="https://www.instagram.com/spellenrijk" target="_blank" rel="nofollow" itemprop="email"><i class="fa  fa-instagram"></i></a>
	</span> 
<br>
<!-- Feedback Company Widget (start) -->
<script type="text/javascript" id="__fbcw__a79d0566-a720-4cc8-a3eb-06a10e74d0cc">
    "use strict";!function(){
window.FeedbackCompanyWidgets=window.FeedbackCompanyWidgets||{queue:[],loaders:[
]};var options={uuid:"a79d0566-a720-4cc8-a3eb-06a10e74d0cc",version:"1.2.1",prefix:""};if(
void 0===window.FeedbackCompanyWidget){if(
window.FeedbackCompanyWidgets.queue.push(options),!document.getElementById(
"__fbcw_FeedbackCompanyWidget")){var scriptTag=document.createElement("script")
;scriptTag.onload=function(){if(window.FeedbackCompanyWidget)for(
;0<window.FeedbackCompanyWidgets.queue.length;
)options=window.FeedbackCompanyWidgets.queue.pop(),
window.FeedbackCompanyWidgets.loaders.push(
new window.FeedbackCompanyWidgetLoader(options))},
scriptTag.id="__fbcw_FeedbackCompanyWidget",
scriptTag.src="https://www.feedbackcompany.com/includes/widgets/feedback-company-widget.min.js"
,document.body.appendChild(scriptTag)}
}else window.FeedbackCompanyWidgets.loaders.push(
new window.FeedbackCompanyWidgetLoader(options))}();
</script>
<!-- Feedback Company Widget (end) -->
</p>
</div>
</div>
</div>
</div>
</div>
</div>
<div class='wrapper100 wrapper100-copyfooter'>
<div class='blockcontainer wrapper-content wrapper-copyfooter'>
<div id="websiteblok19" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 pagecfg key-next-copy-footer">
<div id="websitecontentblok109" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 element">
<div id="cmscontentblok239" class="box pcw100 pcs0010 tabw100 tabs0010 mobhide cmscfg">
<article class='contentbox cmsinnercontentbox'>
<header><h5>veilig en makkelijk betalen</h5></header>
<div class='cms-styling'>


</div></article>
</div>
</div>
<div id="websitecontentblok146" class="box pcw100 pcs0020 tabw100 tabs0020 mobw100 mobs0020 betaallogos element">
<div id="bannercontentblok52" class="box pcw0 pcs0001 tabw0 tabs0001 mobw0 mobs0001 bannercfg">
<img src="https://www.spellenrijk.nl/resize/thuiswinkel_footer_6901262644398.png/thuiswinkel-waarborg.png" data-src="https://www.spellenrijk.nl/resize/thuiswinkel_footer_6901262644398.png/thuiswinkel-waarborg.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="thuiswinkel waarborg"/>

</div>
<div id="bannercontentblok50" class="box pcw0 pcs0010 tabw0 tabs0010 mobw0 mobs0010 bannercfg">
<img src="https://www.spellenrijk.nl/resize/postnl-logo_8776262632880.png/postnl.png" data-src="https://www.spellenrijk.nl/resize/postnl-logo_8776262632880.png/postnl.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="PostNL"/>

</div>
<div id="bannercontentblok51" class="box pcw0 pcs0020 tabw0 tabs0020 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/bancontact_footer_6901262640840.png/bancontact_footer_6901262640840.png" data-src="https://www.spellenrijk.nl/resize/bancontact_footer_6901262640840.png/bancontact_footer_6901262640840.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Spellenrijk 2020 - Next - Main - SubFooter - Bancontact"/>

</div>
<div id="bannercontentblok49" class="box pcw0 pcs0040 tabw0 tabs0040 mobw0 mobs0040 bannercfg">
<img src="https://www.spellenrijk.nl/resize/ideal_footer_6901262640720.png/ideal.png" data-src="https://www.spellenrijk.nl/resize/ideal_footer_6901262640720.png/ideal.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="iDEAL"/>

</div>
<div id="bannercontentblok48" class="box pcw0 pcs0050 tabw0 tabs0050 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/mastercard_footer_6901262640764.png/mastercard.png" data-src="https://www.spellenrijk.nl/resize/mastercard_footer_6901262640764.png/mastercard.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Mastercard"/>

</div>
<div id="bannercontentblok47" class="box pcw0 pcs0060 tabw0 tabs0060 mobw0 mobs0060 bannercfg">
<img src="https://www.spellenrijk.nl/resize/visa_footer_6901262640781.png/visa.png" data-src="https://www.spellenrijk.nl/resize/visa_footer_6901262640781.png/visa.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Visa"/>

</div>
<div id="bannercontentblok71" class="box pcw0 pcs0070 tabw0 tabs0070 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/maestro_footer_9401262608162.png/maestro.png" data-src="https://www.spellenrijk.nl/resize/maestro_footer_9401262608162.png/maestro.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Maestro"/>

</div>
<div id="bannercontentblok44" class="box pcw0 pcs0075 tabw0 tabs0075 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/afterpay_footer_6901262640757.png/afterpay_footer_6901262640757.png" data-src="https://www.spellenrijk.nl/resize/afterpay_footer_6901262640757.png/afterpay_footer_6901262640757.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Spellenrijk 2020 - Next - Main - SubFooter - Afterpay"/>

</div>
<div id="bannercontentblok70" class="box pcw0 pcs0080 tabw0 tabs0080 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/overboeking_footer_6901262645144.png/overboeking_footer_6901262645144.png" data-src="https://www.spellenrijk.nl/resize/overboeking_footer_6901262645144.png/overboeking_footer_6901262645144.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Spellenrijk 2020 - Next - Main - SubFooter - Bankoverboeking"/>

</div>
<div id="bannercontentblok46" class="box pcw0 pcs0080 tabw0 tabs0080 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/paypal_footer_6901262641207.png/paypal.png" data-src="https://www.spellenrijk.nl/resize/paypal_footer_6901262641207.png/paypal.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Paypal"/>

</div>
<div id="bannercontentblok72" class="box pcw0 pcs0090 tabw0 tabs0090 mobhide bannercfg">
<img src="https://www.spellenrijk.nl/resize/apple-pay-logo_657512577409.png/apple-pay-logo_657512577409.png" data-src="https://www.spellenrijk.nl/resize/apple-pay-logo_657512577409.png/apple-pay-logo_657512577409.png" onerror="this.src='/styles/clients/spellenrijk-2020/img/no-img.svg';this.onerror='';" alt="Spellenrijk 2020 - Next - Main - SubFooter - ApplePay"/>

</div>
</div>
<div id="websitecontentblok108" class="box pcw100 pcs0030 tabw100 tabs0030 mobw100 mobs0030 copyfooter-bottom element">
<div id="cmscontentblok187" class="box pcw100 pcs0010 tabw100 tabs0010 mobw100 mobs0010 cmscfg">

<div class="cmsinnercontentbox" style="margin: 0px; text-align:center;">Alle prijzen zijn incl. BTW &nbsp;-&nbsp; Copyright © 2010 -
<script>document.write(new Date().getFullYear())</script>
 &nbsp;&nbsp;<a title="Spellenrijk" href="https://www.spellenrijk.nl/">Spellenrijk B.V.</a></div>
</div>
</div>
</div>
</div>
</div>

    </div>

    
        <div class="shopnavholder">
            <div id="categories" class="navbox logic-scroll">
                <div class="shopnavheader">
                    <form name='search'
action='/zoeken.html'
onsubmit='return false;'
method='post'
class='search navsearch'>
<input 
required='required' 
maxlength='150' 
value='huzzle' 
type='text' 
class='input-txt' 
autocomplete='off' 
placeholder='Zoeken naar...'/>
<button data-searchpage='zoeken.html' aria-label='Zoeken naar...' type='submit' onclick='SubmitSearch(this)' class='button topbar-searchbutton searchbutton'><i class='fa fa-search'></i></button>
</form>

                    <span class="menu-close"><i class="fa fa-times"></i></span>
                </div>
                <nav>
                    <ul class="menu-topul">
                        <li class='navgroupinloggenmob'><a href='/inloggen.html' rel='nofollow' title='Inloggen ' class='navgroupclick'>Inloggen<i class='fa fa-angle-right'></i></a></li>
                        <li><a href='/' title="Homepage" class="navgroupclick">Home <i class="fa fa-angle-right"></i></a></li>
                        <li><span class='navgroupclick withsub'>Spellen<i class='fa fa-angle-right'></i></span><ul class='navsub'><a href
ick withoutsub'>TweedeKans<i class='fa fa-angle-right'></i></a></li><li><a href='/speelgoed-van-het-jaar/2022/' class='navgroupclick withoutsub'>Speelgoed van het Jaar<i class='fa fa-angle-right'></i></a></li><li><a href='/kerst-tips/' class='navgroupclick withoutsub'>Tips voor Kerst<i class='fa fa-angle-right'></i></a></li><li><a href='/sale/' class='navgroupclick withoutsub'>Aanbiedingen - Sale<i class='fa fa-angle-right'></i></a></li>
                    </ul>
                    <ul class="menu-bottomul">
                        

                        <li class="merkenmenu"><a href='/merken.html'
                            title='Merken' class="navcmsclick withoutsub">Merken <i class="fa fa-angle-right"></i></a></li>

                        
                        <li class="winkelmandjemenu"><a href='/winkelmandje.html'
                            title='Winkelmandje' class="navcmsclick withoutsub">Winkelmandje <i class="fa fa-angle-right"></i></a></li>
                        

                        <li class="verlanglijstmenu"><a href='/verlanglijstje.html'
                            title='Verlanglijstje' class="navcmsclick withoutsub">Verlanglijstje<i class="fa fa-angle-right"></i></a></li>
                        <li class="mijnaccountmenu"><span class='navcmsclick withsub'>Mijn account<i class='fa fa-angle-right'></i></span>
                            <ul class='navsub'>
                                <li><a href='/inloggen.html' rel='nofollow' title='Inloggen' class='navcmsclick withoutsub'>Inloggen <i class='fa fa-angle-right'></i></a></li>
<li><a href='/registreren.html' title='Registreren' class='navcmsclick withoutsub'>Registreren <i class='fa fa-angle-right'></i></a></li>
<li><a href='/inloggen.html?mode=bestellijst' rel='nofollow' title='Bestellijst' class='navcmsclick withoutsub'>Bestellijst <i class='fa fa-angle-right'></i></a></li>
<li><a href='/inloggen.html?mode=bestelhistorie' rel='nofollow' title='Bestelhistorie' class='navcmsclick withoutsub'>Bestelhistorie <i class='fa fa-angle-right'></i></a></li>
<li><a href='/inloggen.html?mode=orders;facturen' rel='nofollow' title='Orders & facturen' class='navcmsclick withoutsub'>Orders & facturen <i class='fa fa-angle-right'></i></a></li>

                            </ul>
                        </li>
                        <li><span class='navcmsclick withsub'>Klantenservice <i class='fa fa-angle-right'></i></span><ul class='navsub'><li><a href='/contact.html' title='Contact' class='navcmsclick withoutsub'>Contact <i class='fa fa-angle-right'></i></a></li>
<li><a href='/i/retouren.html' title='Retouren' class='navcmsclick withoutsub'>Retouren <i class='fa fa-angle-right'></i></a></li>
<li><a href='/i/vragen.html' title='Vragen' class='navcmsclick withoutsub'>Vragen <i class='fa fa-angle-right'></i></a></li>
</ul></li>
                    </ul>
                </nav>
            </div>
        </div>
    

    
        <div class="hide shopuserholder">
            <div id="menuUserMenu" class="logic-scroll logbox">
            </div>
        </div>
    


    
        <div class="hide shopcartholder">
            <div class="logic-scroll cartbox">

                
                <h4 onclick="location.href='/winkelmandje.html';">Winkelmandje</h4>
                <span class="menu-close"><i class="fa fa-times"></i></span>
                <div id="innnershopcartholder">
                    <div class="filterloader" style="display: block">
                        <div class="spinner">
                            <div class="bounce1"></div>
                            <div class="bounce2"></div>
                            <div class="bounce3"></div>
                        </div>
                    </div>
                </div>
                <div>
                    
                </div>
            </div>
        </div>
    

    

    
        <div class="hide shopfilterholder">
            <div class="filterloader">
                <div class="spinner">
                    <div class="bounce1"></div>
                    <div class="bounce2"></div>
                    <div class="bounce3"></div>
                </div>
            </div>
            <div class="logic-scroll filterbox">
                <div class="filterbox-header">
                    <span class="clear-filters" onclick="ResetFilter();">Wis filters</span>
                    <h4>Filter</h4>
                    <span class="menu-close"><i class="fa fa-times"></i></span>
                </div>
                <div id="innerproductlistfilterformobiel" class="innerproductlistfilter innerproductlistfilterformobiel"></div>

            </div>
        </div>
    



    


    <div class="buypopupholder"></div>

    <div class="shopcover"></div>
    <div class="backtotop-btn"><i class="fa fa-toggle-up"></i></div>
    <div class="bestellijstpopupholder"></div>

    

    <div id="gpHolder" class="generic-popup-holder hide">
        <span class="generic-popup-close" onclick="CloseGenericPopup();"><i class="fa fa-times"></i></span>
        <div id="gpHeader" class="generic-popup-header">
            <h4 id="gpTitle"></h4>
        </div>
        <div id="gpContent" class="generic-popup-content"></div>
        <div id="gpCta" class="generic-popup-cta">
            <div id="ctaCancel" onclick="CloseGenericPopup();">Annuleren</div>
            <div id="ctaConfirm">Bevestigen</div>
        </div>
    </div>

    

    

    
    <!--[if lte IE 9]><p class="oldbrowser">U gebruikt een verouderde browser. <a href="http://browsehappy.com/">Vernieuw uw browser</a> om deze website optimaal weer te geven.</p><![endif]-->

    
    <script type='text/javascript'>
var google_tag_params = {
ecomm_prodid: ['515117','515084','515055','515044','515058','515114','515097','515035','515068','515115','515085','515118','515066','515113','515095','515116','515003','515082','515041','515053','515014','515033','515064','515111','515056','515096','515037','515083','515065','515002','515043','515034','515057','515016','515088','515081','515089','515004','515038','515039','515093','515015','515040','515052','515091','515062','515013','515011','515119','515012','515061','515054','515001','515005','515090','515063','515112','515087','515094','515051','515086','515120','515032','515042','515017','515092','515031','515059','515060','515067','515036'],
ecomm_pagetype: 'searchresults',
ecomm_category: 'Zoekopdracht: huzzle'
};
</script>
<!-- Google Code for Lead Adwords - Conversion Page -->
<script type='text/javascript'>
/* <![CDATA[ */
var google_conversion_id = 1002655483;
var google_conversion_language = "nl";
var google_conversion_format = "2";
var google_conversion_color = "ffffff";
var google_conversion_label = "0fDvCOWb-gEQ-52N3gM";
var google_remarketing_only = true;
var google_custom_params = window.google_tag_params;
/* ]]> */
</script>
<div style='display:none'>
<script type='text/javascript' src='https://www.googleadservices.com/pagead/conversion.js'></script>
</div>
<noscript>
<div style='display:inline;'>
<img height='1' width='1' style='border-style:none;' alt='' src='https://www.googleadservices.com/pagead/conversion/1002655483/?label=0fDvCOWb-gEQ-52N3gM&amp;guid=ON&amp;script=0'/>
</div>
</noscript>

    

    <style>

/* aanpassing review-sterren kleiner*/

.productlist-stars .starholder>i {
font-size: 1.2rem;
}

/* aanpassing aantal reviews tekst kleiner*/ 

.productlist-stars a {
font-size: 11px;
}

/* aanpassing voorraadstatus weergave laats bekeken producten*/ 

.wrapper100-lastviewedproductlist .productlist-stock {
display: none;
}

/* aanpassing lettergrootte menu knoppen in menubalk*/ 

.menubar-holder2-v1 li.nav-main a.nav-main {
font-size: 1.4rem!important;
}

/* aanpassing kleur plus en min knoppen in winkelwagen*/ 

.pcart-cartholder table td .pcart-amount .btn-quantity-minus {
background: #626262;
}
.pcart-cartholder table td .pcart-amount .btn-quantity-plus {
background: #626262;
}

/* aanpassing kleur plus en min knoppen op productpagina*/ 

.pdetail-buyholder .innerbuyholder .btn-quantity-minus {
background: #626262;
}
.pdetail-buyholder .innerbuyholder .btn-quantity-plus {
background: #626262;
}

/* aanpassing kleur USP lijst op productpagina*/

.pdetail-cmsuspholder ul .fa-li {
color: #2c2c2c;
}
.pdetail-cmsuspholder ul li {
color: #2c2c2c;
}

/* aanpassing productpagina H1 titel kleiner lettertype*/ 

h1 {
    color: #2f86c9;
    font-size: 2.5rem;
    font-weight: 700;
    line-height: 3.5rem;
    color: #2c2c2c;
}
</style><script>function InitJquery(){}</script><script defer='defer' src="https://www.dwin1.com/12893.js" type='text/javascript'></script>
    

    <script>
var UseGA = true;
var UseGtagInsteadOfAnalytics = false;
var UseGoogleTagManagerEvent = true;
var UseFacebookPixelEvent = false;
var UseDatatricsPixelEvent = false;
var ShowDebtorWebshopProductListLabels = false;
var CurrencySymbol = '€';
var CurrencyIsoCode = 'EUR';
var WebshopCountryShortCode = 'nl-nl';
var VatToggleExcluding = 'Incl. BTW';
var VatToggleIncluding = 'Excl. BTW';
var ShowAdressUnknownWarning = true;
var UseGlobalSearchAsBaseSearcherInsteadOfSuggestionOrCategory = false;
var ShowProductInformationPopupOnExplodedViews = false;
var DisplayPriceZeroCentsAsDash = false;
var SlickRandomSliderUseCeilInsteadOfFloor = false;
var VatInclusiveLeading = true;
var DeviceOnServer = 'PC';
var ExecuteCartCount = true;
var Lang = 'nl';
var ShoppingCartUrl = '';
var NavigateToShoppingCartConfig = '';
var JsVersion = '221025131516';
var EnablePushState = true;
</script>

    <script src='/js/all.min.js?v=221025131516' type='text/javascript' onload='InitJquery(); AfterInit();' async></script>

    

    
    
    <style>.fa { font-family: 'Font Awesome 5 Pro'; font-weight: 400 !important; }</style><link rel="preconnect" href="https://cdn.logic4.nl"><link rel="stylesheet" href="https://cdn.logic4.nl/FontAwesome/5/latest/css/all.min.css?v=21122022">
                <link rel="stylesheet" href="https://cdn.logic4.nl/FontAwesome/5/latest/css/brands.min.css?v=21122022">
                <link rel="stylesheet" href="https://cdn.logic4.nl/FontAwesome/5/latest/css/v4-shims.min.css?v=21122022">
                <link rel="stylesheet" href="https://cdn.logic4.nl/FontAwesome/5/custom_shims/custom-shims.css?v=21122022">
</body>
</html>
"""

# %%
import re
puzzles = re.findall("data-productname='(.*?)'", html)
#data-productname='Huzzle Cast Puzzle - Violon (level 3)'
print(len(puzzles))
puzzles = set(puzzles)
print(len(puzzles))
#puzzles
# Out:
# 139
# 71

# %%
puzzles = [x.split(' - ')[1].split(' (') for x in puzzles]
print(puzzles)
puzzles = [(int(x[1].split(' ')[1][:-1]), x[0]) for x in puzzles]
puzzles
# Out:
# [['Box', 'level 2)'], ['Enigma', 'level 6)'], ['Cyclone', 'level 5)'], ['Hexagon', 'level 4)'], ['Key II', 'level 2)'], ['UFO', 'level 4)'], ['Cake', 'level 4)'], ['Slider', 'Level 3)'], ['Spiral', 'level 5)'], ['Trinity', 'level 6)'], ['Donuts', 'level 4)'], ['Violon', 'level 3)'], ['Galaxy', 'level 3)'], ['Heart', 'level 4)'], ['News', 'level 6)'], ['Radix', 'level 5)'], ['Diamond', 'level 1)'], ['Dolce', 'level 3)'], ['Arrows', 'level 3)'], ['Infinity', 'level 6)'], ['ABC', 'level 1)'], ['Cage', 'level 3)'], ['Twist', 'level 4)'], ['Dot', 'level 2)'], ['Flag', 'level 1)'], ['Cross', 'level 3)'], ['Dial', 'level 4)'], ['Love', 'level 1)'], ['Marble', 'level 5)'], ['Hook', 'level 2)'], ['Star', 'level 3)'], ['U&U', 'level 4)'], ['Hashtag', 'level 3)'], ['Equa', 'level 5)'], ['Dice', 'level 3)'], ['Harmony', 'level 2)'], ['Square', 'level 5)'], ['Quartet', 'level 6)'], ['Baroq', 'level 4)'], ['Delta', 'level 3)'], ['Helix', 'level 5)'], ['Horse', 'level 2)'], ['Mobius', 'level 4)'], 
# ...

# %%
puzzles = set(puzzles)
puzzles = puzzles -  set({(6, 'Enigma'), (5, "Devil"), (3, "Star")})
#puzzles -= set((5, "Devil")) 
#puzzles -= set((3, "Star")) 
puzzles
# Out:
# {(1, 'ABC'),
#  (1, 'Diamond'),
#  (1, 'Flag'),
#  (1, 'Loop'),
#  (1, 'Love'),
#  (2, 'Box'),
#  (2, 'Dot'),
#  (2, 'Harmony'),
#  (2, 'Hook'),
#  (2, 'Horse'),
#  (2, 'Key II'),
#  (2, 'Snow'),
#  (3, 'Arrows'),
#  (3, 'Cage'),
#  (3, 'Cross'),
#  (3, 'Delta'),
#  (3, 'Dice'),
#  (3, 'Dolce'),
#  (3, 'G&G'),
#  (3, 'Galaxy'),
#  (3, 'Hashtag'),
#  (3, 'O&apos;gear'),
#  (3, 'S&S'),
#  (3, 'Slider'),
#  (3, 'Violon'),
#  (4, 'Baroq'),
#  (4, 'Cake'),
#  (4, 'Coaster'),
#  (4, 'Coil'),
#  (4, 'Cylinder'),
#  (4, 'Dial'),
#  (4, 'Donuts'),
#  (4, 'Heart'),
#  (4, 'Hexagon'),
#  (4, 'Keyhole'),
#  (4, 'L&apos;Oeuf'),
#  (4, 'Mobius'),
#  (4, 'Planet'),
#  (4, 'Ring'),
#  (4, 'Twist'),
#  (4, 'U&U'),
#  (4, 'UFO'),
#  (4, 'Valve'),
#  (5, 'Amour'),
#  (5, 'Cyclone'),
#  (5, 'Duet'),
#  (5, 'Elk'),
#  (5, 'Equa'),
#  (5, 'H&H'),
#  (5, 'Helix'),
#  (5, 'Laby'),
#  (5, 'Marble'),
#  (5, 'Padlock'),
#  (5, 'Radix'),
#  (5, 'Rattle'),
#  (5, 'Ring II'),
#  (5, 'Spiral'),
#  (5, 'Square'),
# ...

# %%
#puzzles = list(sorted(list(puzzles)))

# %%
puzzles = list(puzzles)
puzzles
# Out:
# [(3, 'Slider'),
#  (2, 'Harmony'),
#  (3, 'Cage'),
#  (4, 'UFO'),
#  (5, 'H&H'),
#  (3, 'Galaxy'),
#  (3, 'Cross'),
#  (4, 'Mobius'),
#  (3, 'Violon'),
#  (6, 'Nutcase'),
#  (4, 'Heart'),
#  (5, 'Square'),
#  (3, 'Dolce'),
#  (5, 'Elk'),
#  (1, 'ABC'),
#  (2, 'Key II'),
#  (4, 'Coaster'),
#  (6, 'Trinity'),
#  (5, 'Marble'),
#  (5, 'Ring II'),
#  (5, 'Spiral'),
#  (5, 'Rattle'),
#  (4, 'U&U'),
#  (6, 'News'),
#  (5, 'Helix'),
#  (1, 'Loop'),
#  (4, 'Cylinder'),
#  (4, 'L&apos;Oeuf'),
#  (1, 'Love'),
#  (4, 'Keyhole'),
#  (3, 'S&S'),
#  (2, 'Hook'),
#  (5, 'Tube'),
#  (5, 'Amour'),
#  (1, 'Flag'),
#  (5, 'Cyclone'),
#  (2, 'Box'),
#  (5, 'Laby'),
#  (6, 'Hourglass'),
#  (4, 'Hexagon'),
#  (4, 'Planet'),
#  (6, 'Vortex'),
#  (6, 'Quartet'),
#  (3, 'G&G'),
#  (5, 'Padlock'),
#  (2, 'Horse'),
#  (5, 'Radix'),
#  (3, 'Arrows'),
#  (4, 'Dial'),
#  (3, 'Delta'),
#  (3, 'O&apos;gear'),
#  (3, 'Dice'),
#  (2, 'Snow'),
#  (6, 'Infinity'),
#  (4, 'Twist'),
#  (4, 'Valve'),
#  (3, 'Hashtag'),
# ...

# %%
import hashlib
  
# encoding GeeksforGeeks using md5 hash
# function 

groepen = [b"karelsusan", b"karsten", b"tijnjitske", b"harryjacqueline", b"andrew", b"johanpauline"]
    
groepen_hash = [[x,int(hashlib.md5(x).hexdigest(), 16)] for x in groepen]
groepen_hash
# Out:
# [[b'karelsusan', 93632723269573793028232705772048031544],
#  [b'karsten', 321746254909433046859116825221975261651],
#  [b'tijnjitske', 252951366304267707023128921221544930661],
#  [b'harryjacqueline', 81214951384424556914543831077910686830],
#  [b'andrew', 288550943903704096876987639143721531659],
#  [b'johanpauline', 222099178961986555440168416457617890691]]

# %%
allowed = {
'karelsusan': [2,3,4,5],
'karsten': [3,4,5,6],
'tijnjitske': [4,5,6],
'harryjacqueline': [1,2,3,4],
'andrew': [3,4,5],
'johanpauline': [1,2,3,4]
}

# %%
for groep, g_hash in groepen_hash:
    allowed_levels = allowed[groep.decode('ascii')]
    unique_puzzles = [x for x in puzzles if x[0] in allowed_levels]
    print(f"{groep.decode('ascii')} krijgen {unique_puzzles[g_hash % len(unique_puzzles)]}")
# Out:
# karelsusan krijgen (5, 'Ring II')
# karsten krijgen (5, 'H&H')
# tijnjitske krijgen (6, 'Infinity')
# harryjacqueline krijgen (4, 'Heart')
# andrew krijgen (5, 'Padlock')
# johanpauline krijgen (1, 'Loop')

# %%
#karelsusan krijgen (5, 'Ring II')
#karsten krijgen (5, 'H&H')
#tijnjitske krijgen (6, 'Infinity')
#harryjacqueline krijgen (4, 'Heart')
#andrew krijgen (5, 'Padlock')
#johanpauline krijgen (1, 'Loop')
