# %%
print(sum(1 for row in open("input_12.txt").read().rstrip().split("\n\n")[-1].split("\n") if int(row.split(": ")[0].split("x")[0]) * int(row.split(": ")[0].split("x")[1]) >= sum(map(int, row.split(": ")[1].split())) * 7))
# Out:
# 406
