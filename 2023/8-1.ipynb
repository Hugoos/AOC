# %%
import helpers
import numpy as np

#helpers.npNicePrint(arr)

data = """LLR

AAA = (BBB, BBB)
BBB = (AAA, ZZZ)
ZZZ = (ZZZ, ZZZ)"""
with open("input_8.txt", 'r') as f:
    data = f.read().strip()

#data = data.split('\n\n')
    
instruction = data.split('\n\n')[0]

nodes = []
left_nodes = []
right_nodes = []

network_dict = {}

instructions = data.split('\n\n')[1].split("\n")

for row in instructions:
    stripped_string = row.replace('(', '').replace(')', '').replace(' ', '')
    components = stripped_string.split('=')
    name = components[0].strip()
    values = components[1].split(',')
    values = [val.strip() for val in values]
    network_dict[name] = {"L": values[0], "R": values[1]}
    
print(instruction)   
network_dict
# Out:
# 
# {'TNX': {'L': 'BBN', 'R': 'MXH'},
#  'TCN': {'L': 'VBD', 'R': 'LTV'},
#  'DXP': {'L': 'GMJ', 'R': 'CMG'},
#  'RRM': {'L': 'FHL', 'R': 'FHB'},
#  'DFG': {'L': 'MVT', 'R': 'FTP'},
#  'GFJ': {'L': 'TRG', 'R': 'LFT'},
#  'FKL': {'L': 'SFR', 'R': 'NRR'},
#  'GMJ': {'L': 'RRM', 'R': 'NRT'},
#  'FPM': {'L': 'GTQ', 'R': 'NSH'},
#  'RKL': {'L': 'DSC', 'R': 'VNR'},
#  'RXK': {'L': 'RQR', 'R': 'TQX'},
#  'GGV': {'L': 'DFG', 'R': 'TNJ'},
#  'KVR': {'L': 'BBD', 'R': 'RHV'},
#  'RVJ': {'L': 'MVJ', 'R': 'MNN'},
#  'XCM': {'L': 'QMM', 'R': 'BTG'},
#  'PMS': {'L': 'PRQ', 'R': 'BMN'},
#  'BHM': {'L': 'QGQ', 'R': 'KNC'},
#  'FMC': {'L': 'NTT', 'R': 'HDH'},
#  'BNX': {'L': 'DSC', 'R': 'VNR'},
#  'QSJ': {'L': 'XFR', 'R': 'JMV'},
# ...

# %%
node = "AAA"
ptr = 0
while not node == "ZZZ":
    print(node, instruction[ptr%len(instruction)])
    node = network_dict[node][instruction[ptr%len(instruction)]]
    ptr += 1
ptr
# Out:
# AAA L
# PFM R
# BNX L
# DSC R
# TKG R
# KBD L
# VDG R
# KMH L
# BBD R
# GQX L
# GKR L
# PBX R
# SPV R
# QFV R
# CGK L
# HQT L
# CBT L
# JNV R
# MQB L
# SFT L
# BPC R
# CVT R
# JQM L
# THR L
# LVL R
# DFG R
# FTP R
# LHV L
# LDH R
# LGG L
# HKC R
# LSH L
# LJT R
# VLH R
# CQD R
# DDM L
# XKS R
# LFN R
# PHG L
# JFC R
# LCX L
# QQF R
# CRN R
# HXK R
# BVQ L
# LMF R
# GCR R
# SLQ R
# RXG L
# NDV R
# FDR R
# TJN R
# FDQ L
# MXT R
# VHN R
# JGQ R
# RTF L
# CKR R
# DCS R
# LNH L
# PGN R
# QNM R
# PRT R
# JPS L
# TRG R
# FMQ R
# VQL R
# VMK L
# KKX R
# MQL R
# SXF L
# RXX L
# FMR L
# LXR R
# NLX L
# RKL L
# DSC R
# TKG L
# VDR R
# MNV R
# KMH R
# RHV L
# XRD R
# GKR R
# JPV R
# SPV L
# PJL R
# CGK R
# HTH L
# CBT R
# GJN L
# MQB R
# MRD L
# VGR R
# RSF L
# JQM R
# QFG R
# GGV R
# TNJ L
# FTP R
# LHV R
# MVQ R
# LGG L
# HKC R
# LSH R
# QBL R
# VLH L
# DMF R
# DDM R
# QTC L
# JMJ R
# PHG R
# PPN L
# MKK R
# QQF R
# CRN L
# PFP L
# BVQ R
# XKQ R
# GCR L
# SKM R
# RXG R
# SVB R
# CKF L
# TJN L
# ...

# %%
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes to the graph
G.add_nodes_from([1, 2, 3, 4, 5])

# Add some initial edges
G.add_edge(1, 2)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

# Function to update edges dynamically
def update_edges():
    # Your logic to update edges goes here
    # For example, remove an existing edge and add a new one
    G.remove_edge(2, 3)
    G.add_edge(2, 4)

# Update edges dynamically
update_edges()

# Nodes for which you want to find the shortest path
source_node = 1
target_node = 5

# Find the shortest path
shortest_path = nx.shortest_path(G, source=source_node, target=target_node)

print("Shortest path:", shortest_path)
# Out:
# Shortest path: [1, 2, 4, 5]
