# %%
from helpers import npNicePrint
import numpy as np
import ast

#helpers.npNicePrint(arr)


data = """broadcaster -> a
# %a -> inv, con
&inv -> b
# %b -> con
&con -> output"""

with open("input_20.txt", 'r') as f:
    data = f.read().strip()

modules = {}

for row in data.split("\n"):
    mdl, targets= row.split(" -> ")
    targets = targets.split(", ")
    mdl_type = None
    if "%" in mdl:
        mdl_type = "%"
        mdl = mdl[1:]
    elif "&" in mdl:
        mdl_type = "&"
        mdl = mdl[1:]
        
    
    if not mdl in modules:
        if mdl_type == "&":
            modules[mdl] = {"value": 0, "mdl_type": mdl_type, "targets": targets, "inputs": {}}
        else:
            modules[mdl] = {"value": 0, "mdl_type": mdl_type, "targets": targets}

for row in data.split("\n"):
    mdl, targets= row.split(" -> ")
    targets = targets.split(", ")
    
    if "%" in mdl:
        mdl_type = "%"
        mdl = mdl[1:]
    elif "&" in mdl:
        mdl_type = "&"
        mdl = mdl[1:]

    for target in targets:
        if not target in modules:
            modules[target] = {"value": 0, "mdl_type": None}
        if 'inputs' in modules[target].keys():
            if not mdl in modules[target]['inputs']:
                modules[target]['inputs'][mdl] = 0

    
            
#modules

# %%
from collections import deque

nicing = {0: "-low->", 1: "-high->"}



low_pulses = 0
high_pulses = 0

lowest_cycle = {'kr': 1000000000000000, 'zs': 100000000000000, 'kf': 1000000000000, 'qk': 10000000000000000}

for x in range(10000000000000):
    signal_queue = deque()
    signal_queue.append(["button", "broadcaster", 0])
    
    while len(signal_queue) > 0:
        previous_node, next_node, value = signal_queue.popleft()
        
        if next_node in lowest_cycle.keys() and value == 0:
            print( previous_node, next_node, value)
            if (x+1) < lowest_cycle[next_node]:
                lowest_cycle[next_node] = (x+1)
                print(lowest_cycle)
        
        if next_node == "rx" and value == 0:
            print(f"answer {x+1}")
        #print(previous_node, nicing[value], next_node)
        if value == 0:
            low_pulses += 1
        elif value == 1:
            high_pulses += 1
        if next_node == "broadcaster":
            modules[next_node]['value'] = value
            for target in modules[next_node]['targets']:
                signal_queue.append([next_node, target, modules[next_node]['value']])
            continue
        mdl_type = modules[next_node]['mdl_type']
        if mdl_type == "%" and value == 0:
            modules[next_node]['value'] = (modules[next_node]['value'] + 1) % 2
            for target in modules[next_node]['targets']:
                signal_queue.append([next_node, target, modules[next_node]['value']])

        if mdl_type == "&":
            modules[next_node]['inputs'][previous_node] = value
            for target in modules[next_node]['targets']:
                signal_queue.append([next_node, target, int(not all(value == 1 for value in modules[next_node]['inputs'].values()))])
    
#print(low_pulses, high_pulses, low_pulses * high_pulses)
# Out:
# bf kr 0
# {'kr': 3761, 'zs': 100000000000000, 'kf': 1000000000000, 'qk': 10000000000000000}
# gm kf 0
# {'kr': 3761, 'zs': 100000000000000, 'kf': 3767, 'qk': 10000000000000000}
# qr qk 0
# {'kr': 3761, 'zs': 100000000000000, 'kf': 3767, 'qk': 4001}
# cx zs 0
# {'kr': 3761, 'zs': 4091, 'kf': 3767, 'qk': 4001}
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# qr qk 0
# cx zs 0
# bf kr 0
# gm kf 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40196/2403464678.py in <module>
#      44             modules[next_node]['inputs'][previous_node] = value
#      45             for target in modules[next_node]['targets']:
# ---> 46                 signal_queue.append([next_node, target, int(not all(value == 1 for value in modules[next_node]['inputs'].values()))])
#      47
#      48 #print(low_pulses, high_pulses, low_pulses * high_pulses)
#
# KeyboardInterrupt:

# %%
import numpy as np

np.lcm.reduce(np.array(list(lowest_cycle.values()), dtype=np.int64))
# Out:
# 231897990075517

# %%
modules
# Out:
# {'mh': {'value': 1, 'mdl_type': '%', 'targets': ['rz']},
#  'nd': {'value': 1, 'mdl_type': '%', 'targets': ['jx']},
#  'xt': {'value': 0, 'mdl_type': '%', 'targets': ['cx']},
#  'dp': {'value': 0, 'mdl_type': '%', 'targets': ['mh']},
#  'pz': {'value': 1, 'mdl_type': '%', 'targets': ['zg', 'bf']},
#  'rp': {'value': 0, 'mdl_type': '%', 'targets': ['jb', 'bf']},
#  'jb': {'value': 0, 'mdl_type': '%', 'targets': ['bf', 'kp']},
#  'rj': {'value': 0, 'mdl_type': '%', 'targets': ['xt', 'cx']},
#  'hg': {'value': 0, 'mdl_type': '%', 'targets': ['dl', 'bf']},
#  'pt': {'value': 0, 'mdl_type': '%', 'targets': ['gm', 'vv']},
#  'pf': {'value': 0, 'mdl_type': '%', 'targets': ['xk', 'qr']},
#  'cv': {'value': 0, 'mdl_type': '%', 'targets': ['jp', 'cx']},
#  'zg': {'value': 0, 'mdl_type': '%', 'targets': ['bb']},
#  'qn': {'value': 1, 'mdl_type': '%', 'targets': ['gm', 'bh']},
#  'kp': {'value': 1, 'mdl_type': '%', 'targets': ['pz']},
#  'kg': {'value': 0, 'mdl_type': '%', 'targets': ['gm', 'pt']},
#  'sl': {'value': 1, 'mdl_type': '%', 'targets': ['rp']},
#  'dz': {'value': 0, 'mdl_type': '%', 'targets': ['bf', 'dc']},
#  'hm': {'value': 0, 'mdl_type': '%', 'targets': ['cx', 'tz']},
#  'dc': {'value': 1, 'mdl_type': '%', 'targets': ['fk']},
#  'xk': {'value': 0, 'mdl_type': '%', 'targets': ['qr', 'sf']},
#  'kr': {'value': 0, 'mdl_type': '&', 'targets': ['gf'], 'inputs': {'bf': 1}},
#  'bq': {'value': 0, 'mdl_type': '%', 'targets': ['qr', 'mg']},
#  'sf': {'value': 0, 'mdl_type': '%', 'targets': ['qr']},
#  'cx': {'value': 0,
#   'mdl_type': '&',
#   'targets': ['ff', 'vx', 'zs'],
#   'inputs': {'xt': 0,
#    'rj': 0,
#    'cv': 0,
#    'hm': 0,
#    'mf': 1,
#    'sx': 0,
#    'tz': 0,
#    'jp': 0,
#    'kt': 0,
#    'vl': 0,
#    'ff': 0}},
#  'hr': {'value': 1, 'mdl_type': '%', 'targets': ['fq', 'gm']},
#  'ls': {'value': 0, 'mdl_type': '%', 'targets': ['lf', 'gm']},
#  'mf': {'value': 1, 'mdl_type': '%', 'targets': ['cx', 'sx']},
#  'vq': {'value': 0, 'mdl_type': '%', 'targets': ['gm']},
#  'sx': {'value': 0, 'mdl_type': '%', 'targets': ['cx', 'rj']},
#  'gm': {'value': 0,
#   'mdl_type': '&',
#   'targets': ['kg', 'kf', 'fq', 'nc', 'lf'],
#   'inputs': {'pt': 0,
#    'qn': 1,
#    'kg': 0,
#    'hr': 1,
#    'ls': 0,
#    'vq': 0,
#    'bh': 0,
#    'gb': 0,
#    'vv': 1}},
#  'jx': {'value': 1, 'mdl_type': '%', 'targets': ['qr', 'zz']},
#  'tz': {'value': 1, 'mdl_type': '%', 'targets': ['mf', 'cx']},
#  'jp': {'value': 0, 'mdl_type': '%', 'targets': ['cx', 'kt']},
#  'bb': {'value': 1, 'mdl_type': '%', 'targets': ['hg', 'bf']},
#  'zz': {'value': 1, 'mdl_type': '%', 'targets': ['pf', 'qr']},
#  'qr': {'value': 0,
#   'mdl_type': '&',
#   'targets': ['dp', 'bq', 'nd', 'rz', 'mg', 'qk', 'mh'],
#   'inputs': {'pf': 0, 'xk': 0, 'bq': 0, 'sf': 0, 'jx': 1, 'zz': 1, 'tj': 0}},
#  'nc': {'value': 0, 'mdl_type': '%', 'targets': ['gb']},
#  'kt': {'value': 0, 'mdl_type': '%', 'targets': ['hm', 'cx']},
#  'mg': {'value': 1, 'mdl_type': '%', 'targets': ['dp']},
#  'dl': {'value': 0, 'mdl_type': '%', 'targets': ['bf']},
#  'zs': {'value': 0, 'mdl_type': '&', 'targets': ['gf'], 'inputs': {'cx': 1}},
#  'bf': {'value': 0,
#   'mdl_type': '&',
#   'targets': ['dz', 'zg', 'kr', 'sl', 'fk', 'kp', 'dc'],
#   'inputs': {'pz': 1, 'rp': 0, 'jb': 0, 'hg': 0, 'dz': 0, 'bb': 1, 'dl': 0}},
#  'bh': {'value': 0, 'mdl_type': '%', 'targets': ['vq', 'gm']},
#  'kf': {'value': 0, 'mdl_type': '&', 'targets': ['gf'], 'inputs': {'gm': 1}},
#  'fq': {'value': 0, 'mdl_type': '%', 'targets': ['qn']},
#  'vl': {'value': 0, 'mdl_type': '%', 'targets': ['vx', 'cx']},
#  'qk': {'value': 0, 'mdl_type': '&', 'targets': ['gf'], 'inputs': {'qr': 1}},
#  'fk': {'value': 0, 'mdl_type': '%', 'targets': ['sl']},
#  'tj': {'value': 0, 'mdl_type': '%', 'targets': ['nd', 'qr']},
#  'gb': {'value': 0, 'mdl_type': '%', 'targets': ['ls', 'gm']},
#  'lf': {'value': 1, 'mdl_type': '%', 'targets': ['hr']},
#  'vx': {'value': 0, 'mdl_type': '%', 'targets': ['cv']},
#  'ff': {'value': 0, 'mdl_type': '%', 'targets': ['vl', 'cx']},
#  'broadcaster': {'value': 0,
#   'mdl_type': None,
#   'targets': ['kg', 'dz', 'ff', 'bq']},
#  'vv': {'value': 1, 'mdl_type': '%', 'targets': ['nc', 'gm']},
#  'gf': {'value': 0,
#   'mdl_type': '&',
#   'targets': ['rx'],
#   'inputs': {'kr': 0, 'zs': 0, 'kf': 0, 'qk': 0}},
#  'rz': {'value': 1, 'mdl_type': '%', 'targets': ['tj']},
#  'rx': {'value': 0, 'mdl_type': None}}
