# %%
import helpers
import numpy as np

EC_day = 1
EC_part = 1

test = False

#helpers.npNicePrint(arr)
if test:
    data = """Vyrdax,Drakzyph,Fyrryn,Elarzris
    R3,L2,R3,L1
    """
else:
    with open(f"everybody_codes_e2025_q{EC_day:02d}_p{EC_part}.txt", 'r') as f:
        data = f.read()
        
#changeDict = {"forward": np.array([1,0]), "down": np.array([0,1]), "up": np.array([0,-1])}
#data = [changeDict[x.split(" ")[0]] * int(x.split(" ")[1]) for x in data.split("\n") if x]
#data = [x.split(' ') for x in data.split('\n') if x]
#np.prod(sum(data))    
data = [x.split(",") for x in data.split('\n') if not x == ""]

name_list = [x.strip() for x  in data[0]]
instructions = [x.strip() for x  in data[1]]
name_list, instructions
# Out:
# (['Urxaril',
#   'Fenalar',
#   'Marnor',
#   'Elvarralis',
#   'Gaereon',
#   'Drethpyr',
#   'Selkaelor',
#   'Zarathaes',
#   'Azmarlyr',
#   'Luthzal'],
#  ['L5', 'R1', 'L3', 'R5', 'L1', 'R2', 'L1', 'R5', 'L1', 'R4', 'L2'])

# %%
change_dict = {
    "R": "+",
    "L": "-"
}
#eval is unsafe :D
instructions = [eval(change_dict[x[0]] + x[1]) for x in instructions]
instructions
# Out:
# [-5, 1, -3, 5, -1, 2, -1, 5, -1, 4, -2]

# %%
ans = []
i = 0
for instruction in instructions:
    i = max(min(i + instruction, len(name_list)-1),0) # bounded [0, len(name_list)-1]
    ans.append(name_list[i])
ans[-1]
# Out:
# 'Zarathaes'
